# %% [markdown]
# ##YOLOv1 Implementation

# %%
import torch
from torch import nn
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from PIL import Image
import os

# %% [markdown]
# ###Load Data

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !unzip /content/drive/MyDrive/CS5242/labels.zip
# Out:
# Archive:  /content/drive/MyDrive/CS5242/labels.zip
#    creating: content/labels/
#   inflating: content/labels/1471.txt
#   inflating: content/labels/3079.txt
#   inflating: content/labels/154.txt
#   inflating: content/labels/1646.txt
#   inflating: content/labels/422.txt
#   inflating: content/labels/3472.txt
#   inflating: content/labels/3003.txt
#   inflating: content/labels/1943.txt
#   inflating: content/labels/2387.txt
#   inflating: content/labels/1762.txt
#   inflating: content/labels/1095.txt
#   inflating: content/labels/1674.txt
#   inflating: content/labels/1163.txt
#   inflating: content/labels/698.txt
#   inflating: content/labels/2544.txt
#   inflating: content/labels/2073.txt
#   inflating: content/labels/2701.txt
#   inflating: content/labels/1757.txt
#   inflating: content/labels/259.txt
#   inflating: content/labels/646.txt
#   inflating: content/labels/1265.txt
#   inflating: content/labels/2969.txt
#   inflating: content/labels/397.txt
#   inflating: content/labels/1682.txt
#   inflating: content/labels/2980.txt
#   inflating: content/labels/2830.txt
#   inflating: content/labels/1756.txt
#   inflating: content/labels/2349.txt
#   inflating: content/labels/2540.txt
#   inflating: content/labels/3541.txt
#   inflating: content/labels/3312.txt
#   inflating: content/labels/80.txt
#   inflating: content/labels/951.txt
#   inflating: content/labels/1914.txt
#   inflating: content/labels/1271.txt
#   inflating: content/labels/2946.txt
#   inflating: content/labels/3284.txt
#   inflating: content/labels/1787.txt
#   inflating: content/labels/2158.txt
#   inflating: content/labels/2180.txt
#   inflating: content/labels/2628.txt
#   inflating: content/labels/1857.txt
#   inflating: content/labels/3030.txt
#   inflating: content/labels/1237.txt
#   inflating: content/labels/3471.txt
#   inflating: content/labels/1118.txt
#   inflating: content/labels/1248.txt
#   inflating: content/labels/2574.txt
#   inflating: content/labels/859.txt
#   inflating: content/labels/1073.txt
#   inflating: content/labels/476.txt
#   inflating: content/labels/155.txt
#   inflating: content/labels/3420.txt
#   inflating: content/labels/2811.txt
#   inflating: content/labels/3511.txt
#   inflating: content/labels/691.txt
#   inflating: content/labels/2499.txt
#   inflating: content/labels/250.txt
#   inflating: content/labels/2648.txt
#   inflating: content/labels/2227.txt
#   inflating: content/labels/615.txt
#   inflating: content/labels/899.txt
#   inflating: content/labels/1206.txt
#   inflating: content/labels/883.txt
#   inflating: content/labels/1602.txt
#   inflating: content/labels/1617.txt
#   inflating: content/labels/952.txt
#   inflating: content/labels/634.txt
#   inflating: content/labels/2810.txt
#   inflating: content/labels/649.txt
#   inflating: content/labels/2728.txt
#   inflating: content/labels/31.txt
#   inflating: content/labels/3494.txt
#   inflating: content/labels/688.txt
#   inflating: content/labels/1038.txt
#   inflating: content/labels/3346.txt
#   inflating: content/labels/2445.txt
#   inflating: content/labels/1050.txt
#   inflating: content/labels/941.txt
#   inflating: content/labels/976.txt
#   inflating: content/labels/1335.txt
#   inflating: content/labels/2630.txt
#   inflating: content/labels/3218.txt
#   inflating: content/labels/2498.txt
#   inflating: content/labels/3236.txt
#   inflating: content/labels/1994.txt
#   inflating: content/labels/240.txt
#   inflating: content/labels/717.txt
#   inflating: content/labels/724.txt
#   inflating: content/labels/577.txt
#   inflating: content/labels/3350.txt
#   inflating: content/labels/115.txt
#   inflating: content/labels/3280.txt
#   inflating: content/labels/3182.txt
#   inflating: content/labels/3172.txt
#   inflating: content/labels/2455.txt
#   inflating: content/labels/3141.txt
#   inflating: content/labels/1679.txt
#   inflating: content/labels/2405.txt
#   inflating: content/labels/1285.txt
#   inflating: content/labels/3031.txt
#   inflating: content/labels/2590.txt
#   inflating: content/labels/156.txt
#   inflating: content/labels/1492.txt
#   inflating: content/labels/2184.txt
#   inflating: content/labels/1675.txt
#   inflating: content/labels/971.txt
#   inflating: content/labels/2700.txt
#   inflating: content/labels/1378.txt
#   inflating: content/labels/1805.txt
#   inflating: content/labels/1371.txt
#   inflating: content/labels/1010.txt
#   inflating: content/labels/1750.txt
#   inflating: content/labels/1698.txt
#   inflating: content/labels/1531.txt
#   inflating: content/labels/2043.txt
#   inflating: content/labels/566.txt
#   inflating: content/labels/2383.txt
#   inflating: content/labels/182.txt
#   inflating: content/labels/2717.txt
#   inflating: content/labels/2838.txt
#   inflating: content/labels/289.txt
#   inflating: content/labels/512.txt
#   inflating: content/labels/1349.txt
#   inflating: content/labels/2431.txt
#   inflating: content/labels/2448.txt
#   inflating: content/labels/2688.txt
#   inflating: content/labels/1685.txt
#   inflating: content/labels/2610.txt
#   inflating: content/labels/1481.txt
#   inflating: content/labels/1532.txt
#   inflating: content/labels/1490.txt
#   inflating: content/labels/1639.txt
#   inflating: content/labels/3407.txt
#   inflating: content/labels/1372.txt
#   inflating: content/labels/2833.txt
#   inflating: content/labels/2629.txt
#   inflating: content/labels/583.txt
#   inflating: content/labels/609.txt
#   inflating: content/labels/59.txt
#   inflating: content/labels/1137.txt
#   inflating: content/labels/398.txt
#   inflating: content/labels/2432.txt
#   inflating: content/labels/3044.txt
#   inflating: content/labels/968.txt
#   inflating: content/labels/1810.txt
#   inflating: content/labels/1491.txt
#   inflating: content/labels/3187.txt
#   inflating: content/labels/2303.txt
#   inflating: content/labels/3046.txt
#   inflating: content/labels/2479.txt
#   inflating: content/labels/3477.txt
#   inflating: content/labels/561.txt
#   inflating: content/labels/1772.txt
#   inflating: content/labels/1190.txt
#   inflating: content/labels/3495.txt
#   inflating: content/labels/2598.txt
#   inflating: content/labels/1721.txt
#   inflating: content/labels/2914.txt
#   inflating: content/labels/2209.txt
#   inflating: content/labels/3257.txt
#   inflating: content/labels/2711.txt
#   inflating: content/labels/2640.txt
#   inflating: content/labels/2215.txt
#   inflating: content/labels/3253.txt
#   inflating: content/labels/1959.txt
#   inflating: content/labels/3268.txt
#   inflating: content/labels/643.txt
#   inflating: content/labels/3089.txt
#   inflating: content/labels/1192.txt
#   inflating: content/labels/474.txt
#   inflating: content/labels/975.txt
#   inflating: content/labels/3067.txt
#   inflating: content/labels/992.txt
#   inflating: content/labels/1448.txt
#   inflating: content/labels/433.txt
#   inflating: content/labels/1719.txt
#   inflating: content/labels/2880.txt
#   inflating: content/labels/3238.txt
#   inflating: content/labels/2031.txt
#   inflating: content/labels/1175.txt
#   inflating: content/labels/2965.txt
#   inflating: content/labels/3381.txt
#   inflating: content/labels/2653.txt
#   inflating: content/labels/621.txt
#   inflating: content/labels/541.txt
#   inflating: content/labels/805.txt
#   inflating: content/labels/391.txt
#   inflating: content/labels/2733.txt
#   inflating: content/labels/1544.txt
#   inflating: content/labels/3323.txt
#   inflating: content/labels/1016.txt
#   inflating: content/labels/2318.txt
#   inflating: content/labels/210.txt
#   inflating: content/labels/1847.txt
#   inflating: content/labels/3081.txt
#   inflating: content/labels/1584.txt
#   inflating: content/labels/1266.txt
#   inflating: content/labels/637.txt
#   inflating: content/labels/3314.txt
#   inflating: content/labels/1526.txt
#   inflating: content/labels/1831.txt
#   inflating: content/labels/439.txt
#   inflating: content/labels/2471.txt
#   inflating: content/labels/2025.txt
#   inflating: content/labels/1557.txt
#   inflating: content/labels/1060.txt
#   inflating: content/labels/1589.txt
#   inflating: content/labels/1074.txt
#   inflating: content/labels/1945.txt
#   inflating: content/labels/161.txt
#   inflating: content/labels/849.txt
#   inflating: content/labels/239.txt
#   inflating: content/labels/876.txt
#   inflating: content/labels/1004.txt
#   inflating: content/labels/450.txt
#   inflating: content/labels/2584.txt
#   inflating: content/labels/1305.txt
#   inflating: content/labels/824.txt
#   inflating: content/labels/306.txt
#   inflating: content/labels/2142.txt
#   inflating: content/labels/2362.txt
#   inflating: content/labels/3025.txt
#   inflating: content/labels/1253.txt
#   inflating: content/labels/1946.txt
#   inflating: content/labels/3207.txt
#   inflating: content/labels/315.txt
#   inflating: content/labels/966.txt
#   inflating: content/labels/2419.txt
#   inflating: content/labels/3438.txt
#   inflating: content/labels/2996.txt
#   inflating: content/labels/2982.txt
#   inflating: content/labels/2742.txt
#   inflating: content/labels/2195.txt
#   inflating: content/labels/2869.txt
#   inflating: content/labels/739.txt
#   inflating: content/labels/1222.txt
#   inflating: content/labels/1146.txt
#   inflating: content/labels/1295.txt
#   inflating: content/labels/2879.txt
#   inflating: content/labels/3136.txt
#   inflating: content/labels/1162.txt
#   inflating: content/labels/1428.txt
#   inflating: content/labels/1472.txt
#   inflating: content/labels/381.txt
#   inflating: content/labels/2841.txt
#   inflating: content/labels/777.txt
#   inflating: content/labels/2316.txt
#   inflating: content/labels/129.txt
#   inflating: content/labels/3427.txt
#   inflating: content/labels/308.txt
#   inflating: content/labels/1634.txt
#   inflating: content/labels/1910.txt
#   inflating: content/labels/1359.txt
#   inflating: content/labels/413.txt
#   inflating: content/labels/2410.txt
#   inflating: content/labels/1049.txt
#   inflating: content/labels/128.txt
#   inflating: content/labels/2901.txt
#   inflating: content/labels/1344.txt
#   inflating: content/labels/1759.txt
#   inflating: content/labels/336.txt
#   inflating: content/labels/351.txt
#   inflating: content/labels/1680.txt
#   inflating: content/labels/1600.txt
#   inflating: content/labels/937.txt
#   inflating: content/labels/3510.txt
#   inflating: content/labels/2903.txt
#   inflating: content/labels/2939.txt
#   inflating: content/labels/1257.txt
#   inflating: content/labels/449.txt
#   inflating: content/labels/851.txt
#   inflating: content/labels/478.txt
#   inflating: content/labels/2784.txt
#   inflating: content/labels/3500.txt
#   inflating: content/labels/2053.txt
#   inflating: content/labels/1529.txt
#   inflating: content/labels/1671.txt
#   inflating: content/labels/1138.txt
#   inflating: content/labels/442.txt
#   inflating: content/labels/1488.txt
#   inflating: content/labels/1194.txt
#   inflating: content/labels/664.txt
#   inflating: content/labels/2641.txt
#   inflating: content/labels/293.txt
#   inflating: content/labels/224.txt
#   inflating: content/labels/2375.txt
#   inflating: content/labels/2983.txt
#   inflating: content/labels/1912.txt
#   inflating: content/labels/1979.txt
#   inflating: content/labels/781.txt
#   inflating: content/labels/2904.txt
#   inflating: content/labels/784.txt
#   inflating: content/labels/480.txt
#   inflating: content/labels/3278.txt
#   inflating: content/labels/1387.txt
#   inflating: content/labels/852.txt
#   inflating: content/labels/390.txt
#   inflating: content/labels/3503.txt
#   inflating: content/labels/1401.txt
#   inflating: content/labels/2122.txt
#   inflating: content/labels/1450.txt
#   inflating: content/labels/1068.txt
#   inflating: content/labels/1516.txt
#   inflating: content/labels/1395.txt
#   inflating: content/labels/117.txt
#   inflating: content/labels/15.txt
#   inflating: content/labels/811.txt
#   inflating: content/labels/271.txt
#   inflating: content/labels/1689.txt
#   inflating: content/labels/2699.txt
#   inflating: content/labels/1435.txt
#   inflating: content/labels/3063.txt
#   inflating: content/labels/2758.txt
#   inflating: content/labels/2863.txt
#   inflating: content/labels/206.txt
#   inflating: content/labels/2304.txt
#   inflating: content/labels/887.txt
#   inflating: content/labels/565.txt
#   inflating: content/labels/1353.txt
#   inflating: content/labels/3165.txt
#   inflating: content/labels/2679.txt
#   inflating: content/labels/2984.txt
#   inflating: content/labels/3455.txt
#   inflating: content/labels/2147.txt
#   inflating: content/labels/1029.txt
#   inflating: content/labels/3193.txt
#   inflating: content/labels/1604.txt
#   inflating: content/labels/2565.txt
#   inflating: content/labels/124.txt
#   inflating: content/labels/2415.txt
#   inflating: content/labels/238.txt
#   inflating: content/labels/3152.txt
#   inflating: content/labels/492.txt
#   inflating: content/labels/599.txt
#   inflating: content/labels/856.txt
#   inflating: content/labels/580.txt
#   inflating: content/labels/2464.txt
#   inflating: content/labels/834.txt
#   inflating: content/labels/1198.txt
#   inflating: content/labels/3519.txt
#   inflating: content/labels/208.txt
#   inflating: content/labels/3484.txt
#   inflating: content/labels/792.txt
#   inflating: content/labels/177.txt
#   inflating: content/labels/64.txt
#   inflating: content/labels/2236.txt
#   inflating: content/labels/3337.txt
#   inflating: content/labels/3374.txt
#   inflating: content/labels/700.txt
#   inflating: content/labels/385.txt
#   inflating: content/labels/2868.txt
#   inflating: content/labels/1743.txt
#   inflating: content/labels/3430.txt
#   inflating: content/labels/320.txt
#   inflating: content/labels/961.txt
#   inflating: content/labels/2820.txt
#   inflating: content/labels/3362.txt
#   inflating: content/labels/672.txt
#   inflating: content/labels/1789.txt
#   inflating: content/labels/2780.txt
#   inflating: content/labels/1802.txt
#   inflating: content/labels/2060.txt
#   inflating: content/labels/298.txt
#   inflating: content/labels/569.txt
#   inflating: content/labels/1235.txt
#   inflating: content/labels/2912.txt
#   inflating: content/labels/2255.txt
#   inflating: content/labels/358.txt
#   inflating: content/labels/165.txt
#   inflating: content/labels/1315.txt
#   inflating: content/labels/1867.txt
#   inflating: content/labels/2384.txt
#   inflating: content/labels/1444.txt
#   inflating: content/labels/3184.txt
#   inflating: content/labels/1103.txt
#   inflating: content/labels/661.txt
#   inflating: content/labels/1577.txt
#   inflating: content/labels/2396.txt
#   inflating: content/labels/894.txt
#   inflating: content/labels/2796.txt
#   inflating: content/labels/2756.txt
#   inflating: content/labels/2023.txt
#   inflating: content/labels/3234.txt
#   inflating: content/labels/3283.txt
#   inflating: content/labels/2323.txt
#   inflating: content/labels/329.txt
#   inflating: content/labels/1570.txt
#   inflating: content/labels/2029.txt
#   inflating: content/labels/1594.txt
#   inflating: content/labels/2921.txt
#   inflating: content/labels/3380.txt
#   inflating: content/labels/2936.txt
#   inflating: content/labels/1824.txt
#   inflating: content/labels/122.txt
#   inflating: content/labels/2644.txt
#   inflating: content/labels/632.txt
#   inflating: content/labels/1837.txt
#   inflating: content/labels/495.txt
#   inflating: content/labels/3231.txt
#   inflating: content/labels/313.txt
#   inflating: content/labels/3149.txt
#   inflating: content/labels/2552.txt
#   inflating: content/labels/2234.txt
#   inflating: content/labels/2846.txt
#   inflating: content/labels/1047.txt
#   inflating: content/labels/532.txt
#   inflating: content/labels/1451.txt
#   inflating: content/labels/1300.txt
#   inflating: content/labels/2571.txt
#   inflating: content/labels/3534.txt
#   inflating: content/labels/3317.txt
#   inflating: content/labels/648.txt
#   inflating: content/labels/702.txt
#   inflating: content/labels/1090.txt
#   inflating: content/labels/20.txt
#   inflating: content/labels/2129.txt
#   inflating: content/labels/2787.txt
#   inflating: content/labels/138.txt
#   inflating: content/labels/145.txt
#   inflating: content/labels/2957.txt
#   inflating: content/labels/2940.txt
#   inflating: content/labels/90.txt
#   inflating: content/labels/2257.txt
#   inflating: content/labels/236.txt
#   inflating: content/labels/890.txt
#   inflating: content/labels/1858.txt
#   inflating: content/labels/926.txt
#   inflating: content/labels/1330.txt
#   inflating: content/labels/1798.txt
#   inflating: content/labels/2024.txt
#   inflating: content/labels/768.txt
#   inflating: content/labels/3204.txt
#   inflating: content/labels/1352.txt
#   inflating: content/labels/3217.txt
#   inflating: content/labels/188.txt
#   inflating: content/labels/2476.txt
#   inflating: content/labels/1439.txt
#   inflating: content/labels/1938.txt
#   inflating: content/labels/720.txt
#   inflating: content/labels/2827.txt
#   inflating: content/labels/494.txt
#   inflating: content/labels/3436.txt
#   inflating: content/labels/1278.txt
#   inflating: content/labels/2240.txt
#   inflating: content/labels/1905.txt
#   inflating: content/labels/2276.txt
#   inflating: content/labels/2658.txt
#   inflating: content/labels/1425.txt
#   inflating: content/labels/35.txt
#   inflating: content/labels/273.txt
#   inflating: content/labels/801.txt
#   inflating: content/labels/3463.txt
#   inflating: content/labels/1096.txt
#   inflating: content/labels/2890.txt
#   inflating: content/labels/1453.txt
#   inflating: content/labels/3428.txt
#   inflating: content/labels/993.txt
#   inflating: content/labels/180.txt
#   inflating: content/labels/1099.txt
#   inflating: content/labels/690.txt
#   inflating: content/labels/2444.txt
#   inflating: content/labels/1410.txt
#   inflating: content/labels/392.txt
#   inflating: content/labels/3460.txt
#   inflating: content/labels/2568.txt
#   inflating: content/labels/2858.txt
#   inflating: content/labels/2960.txt
#   inflating: content/labels/1150.txt
#   inflating: content/labels/999.txt
#   inflating: content/labels/1599.txt
#   inflating: content/labels/263.txt
#   inflating: content/labels/2813.txt
#   inflating: content/labels/1202.txt
#   inflating: content/labels/1916.txt
#   inflating: content/labels/2003.txt
#   inflating: content/labels/1635.txt
#   inflating: content/labels/2414.txt
#   inflating: content/labels/3098.txt
#   inflating: content/labels/3360.txt
#   inflating: content/labels/1815.txt
#   inflating: content/labels/1339.txt
#   inflating: content/labels/1195.txt
#   inflating: content/labels/276.txt
#   inflating: content/labels/1603.txt
#   inflating: content/labels/2309.txt
#   inflating: content/labels/1290.txt
#   inflating: content/labels/374.txt
#   inflating: content/labels/205.txt
#   inflating: content/labels/3134.txt
#   inflating: content/labels/523.txt
#   inflating: content/labels/1424.txt
#   inflating: content/labels/1811.txt
#   inflating: content/labels/2039.txt
#   inflating: content/labels/1320.txt
#   inflating: content/labels/61.txt
#   inflating: content/labels/2625.txt
#   inflating: content/labels/3285.txt
#   inflating: content/labels/187.txt
#   inflating: content/labels/262.txt
#   inflating: content/labels/754.txt
#   inflating: content/labels/416.txt
#   inflating: content/labels/414.txt
#   inflating: content/labels/3243.txt
#   inflating: content/labels/2697.txt
#   inflating: content/labels/1631.txt
#   inflating: content/labels/2199.txt
#   inflating: content/labels/3054.txt
#   inflating: content/labels/2898.txt
#   inflating: content/labels/2063.txt
#   inflating: content/labels/2845.txt
#   inflating: content/labels/1941.txt
#   inflating: content/labels/2036.txt
#   inflating: content/labels/3084.txt
#   inflating: content/labels/2339.txt
#   inflating: content/labels/714.txt
#   inflating: content/labels/3417.txt
#   inflating: content/labels/2913.txt
#   inflating: content/labels/2676.txt
#   inflating: content/labels/708.txt
#   inflating: content/labels/1456.txt
#   inflating: content/labels/820.txt
#   inflating: content/labels/2426.txt
#   inflating: content/labels/2338.txt
#   inflating: content/labels/838.txt
#   inflating: content/labels/2650.txt
#   inflating: content/labels/3042.txt
#   inflating: content/labels/2218.txt
#   inflating: content/labels/409.txt
#   inflating: content/labels/2712.txt
#   inflating: content/labels/2083.txt
#   inflating: content/labels/260.txt
#   inflating: content/labels/3365.txt
#   inflating: content/labels/3450.txt
#   inflating: content/labels/818.txt
#   inflating: content/labels/3160.txt
#   inflating: content/labels/1032.txt
#   inflating: content/labels/798.txt
#   inflating: content/labels/1854.txt
#   inflating: content/labels/605.txt
#   inflating: content/labels/567.txt
#   inflating: content/labels/3179.txt
#   inflating: content/labels/2222.txt
#   inflating: content/labels/1035.txt
#   inflating: content/labels/3364.txt
#   inflating: content/labels/186.txt
#   inflating: content/labels/3226.txt
#   inflating: content/labels/1318.txt
#   inflating: content/labels/1072.txt
#   inflating: content/labels/2775.txt
#   inflating: content/labels/230.txt
#   inflating: content/labels/118.txt
#   inflating: content/labels/2842.txt
#   inflating: content/labels/1969.txt
#   inflating: content/labels/1397.txt
#   inflating: content/labels/1777.txt
#   inflating: content/labels/2985.txt
#   inflating: content/labels/1101.txt
#   inflating: content/labels/269.txt
#   inflating: content/labels/2141.txt
#   inflating: content/labels/3159.txt
#   inflating: content/labels/2778.txt
#   inflating: content/labels/2525.txt
#   inflating: content/labels/50.txt
#   inflating: content/labels/149.txt
#   inflating: content/labels/3113.txt
#   inflating: content/labels/435.txt
#   inflating: content/labels/324.txt
#   inflating: content/labels/3148.txt
#   inflating: content/labels/2686.txt
#   inflating: content/labels/1716.txt
#   inflating: content/labels/3255.txt
#   inflating: content/labels/3546.txt
#   inflating: content/labels/931.txt
#   inflating: content/labels/1624.txt
#   inflating: content/labels/1794.txt
#   inflating: content/labels/3412.txt
#   inflating: content/labels/3102.txt
#   inflating: content/labels/738.txt
#   inflating: content/labels/1184.txt
#   inflating: content/labels/1518.txt
#   inflating: content/labels/3514.txt
#   inflating: content/labels/3151.txt
#   inflating: content/labels/1773.txt
#   inflating: content/labels/1468.txt
#   inflating: content/labels/231.txt
#   inflating: content/labels/2111.txt
#   inflating: content/labels/2504.txt
#   inflating: content/labels/1892.txt
#   inflating: content/labels/1970.txt
#   inflating: content/labels/676.txt
#   inflating: content/labels/948.txt
#   inflating: content/labels/1229.txt
#   inflating: content/labels/2763.txt
#   inflating: content/labels/2106.txt
#   inflating: content/labels/2573.txt
#   inflating: content/labels/1707.txt
#   inflating: content/labels/611.txt
#   inflating: content/labels/656.txt
#   inflating: content/labels/1132.txt
#   inflating: content/labels/2296.txt
#   inflating: content/labels/1647.txt
#   inflating: content/labels/2266.txt
#   inflating: content/labels/2392.txt
#   inflating: content/labels/481.txt
#   inflating: content/labels/1799.txt
#   inflating: content/labels/3048.txt
#   inflating: content/labels/2729.txt
#   inflating: content/labels/1803.txt
#   inflating: content/labels/112.txt
#   inflating: content/labels/519.txt
#   inflating: content/labels/2250.txt
#   inflating: content/labels/1332.txt
#   inflating: content/labels/479.txt
#   inflating: content/labels/2594.txt
#   inflating: content/labels/1280.txt
#   inflating: content/labels/1240.txt
#   inflating: content/labels/426.txt
#   inflating: content/labels/2924.txt
#   inflating: content/labels/1996.txt
#   inflating: content/labels/3041.txt
#   inflating: content/labels/2972.txt
#   inflating: content/labels/787.txt
#   inflating: content/labels/3227.txt
#   inflating: content/labels/2721.txt
#   inflating: content/labels/184.txt
#   inflating: content/labels/823.txt
#   inflating: content/labels/645.txt
#   inflating: content/labels/2789.txt
#   inflating: content/labels/2096.txt
#   inflating: content/labels/2000.txt
#   inflating: content/labels/1473.txt
#   inflating: content/labels/2743.txt
#   inflating: content/labels/2945.txt
#   inflating: content/labels/1031.txt
#   inflating: content/labels/1853.txt
#   inflating: content/labels/881.txt
#   inflating: content/labels/2894.txt
#   inflating: content/labels/1554.txt
#   inflating: content/labels/3542.txt
#   inflating: content/labels/635.txt
#   inflating: content/labels/2579.txt
#   inflating: content/labels/1893.txt
#   inflating: content/labels/1983.txt
#   inflating: content/labels/1735.txt
#   inflating: content/labels/2401.txt
#   inflating: content/labels/1862.txt
#   inflating: content/labels/2657.txt
#   inflating: content/labels/2720.txt
#   inflating: content/labels/1797.txt
#   inflating: content/labels/2458.txt
#   inflating: content/labels/1899.txt
#   inflating: content/labels/2603.txt
#   inflating: content/labels/1688.txt
#   inflating: content/labels/2911.txt
#   inflating: content/labels/1666.txt
#   inflating: content/labels/75.txt
#   inflating: content/labels/1502.txt
#   inflating: content/labels/919.txt
#   inflating: content/labels/178.txt
#   inflating: content/labels/3304.txt
#   inflating: content/labels/1579.txt
#   inflating: content/labels/197.txt
#   inflating: content/labels/813.txt
#   inflating: content/labels/618.txt
#   inflating: content/labels/2163.txt
#   inflating: content/labels/213.txt
#   inflating: content/labels/2853.txt
#   inflating: content/labels/3375.txt
#   inflating: content/labels/613.txt
#   inflating: content/labels/1724.txt
#   inflating: content/labels/247.txt
#   inflating: content/labels/1925.txt
#   inflating: content/labels/758.txt
#   inflating: content/labels/1990.txt
#   inflating: content/labels/1746.txt
#   inflating: content/labels/895.txt
#   inflating: content/labels/731.txt
#   inflating: content/labels/1465.txt
#   inflating: content/labels/1375.txt
#   inflating: content/labels/2987.txt
#   inflating: content/labels/3040.txt
#   inflating: content/labels/1389.txt
#   inflating: content/labels/444.txt
#   inflating: content/labels/2016.txt
#   inflating: content/labels/2042.txt
#   inflating: content/labels/559.txt
#   inflating: content/labels/1522.txt
#   inflating: content/labels/1287.txt
#   inflating: content/labels/1898.txt
#   inflating: content/labels/3006.txt
#   inflating: content/labels/3171.txt
#   inflating: content/labels/1850.txt
#   inflating: content/labels/1152.txt
#   inflating: content/labels/2950.txt
#   inflating: content/labels/328.txt
#   inflating: content/labels/2196.txt
#   inflating: content/labels/1197.txt
#   inflating: content/labels/2032.txt
#   inflating: content/labels/2333.txt
#   inflating: content/labels/1487.txt
#   inflating: content/labels/625.txt
#   inflating: content/labels/2081.txt
#   inflating: content/labels/1504.txt
#   inflating: content/labels/902.txt
#   inflating: content/labels/1075.txt
#   inflating: content/labels/2121.txt
#   inflating: content/labels/715.txt
#   inflating: content/labels/1427.txt
#   inflating: content/labels/3533.txt
#   inflating: content/labels/2102.txt
#   inflating: content/labels/1664.txt
#   inflating: content/labels/2330.txt
#   inflating: content/labels/882.txt
#   inflating: content/labels/1981.txt
#   inflating: content/labels/451.txt
#   inflating: content/labels/2553.txt
#   inflating: content/labels/295.txt
#   inflating: content/labels/108.txt
#   inflating: content/labels/2588.txt
#   inflating: content/labels/1308.txt
#   inflating: content/labels/438.txt
#   inflating: content/labels/17.txt
#   inflating: content/labels/301.txt
#   inflating: content/labels/3197.txt
#   inflating: content/labels/2923.txt
#   inflating: content/labels/2848.txt
#   inflating: content/labels/62.txt
#   inflating: content/labels/2004.txt
#   inflating: content/labels/2694.txt
#   inflating: content/labels/490.txt
#   inflating: content/labels/1238.txt
#   inflating: content/labels/1301.txt
#   inflating: content/labels/2967.txt
#   inflating: content/labels/1140.txt
#   inflating: content/labels/2327.txt
#   inflating: content/labels/3137.txt
#   inflating: content/labels/763.txt
#   inflating: content/labels/1094.txt
#   inflating: content/labels/3539.txt
#   inflating: content/labels/1596.txt
#   inflating: content/labels/147.txt
#   inflating: content/labels/1409.txt
#   inflating: content/labels/2864.txt
#   inflating: content/labels/2794.txt
#   inflating: content/labels/1223.txt
#   inflating: content/labels/2559.txt
#   inflating: content/labels/2782.txt
#   inflating: content/labels/3021.txt
#   inflating: content/labels/607.txt
#   inflating: content/labels/377.txt
#   inflating: content/labels/1641.txt
#   inflating: content/labels/1234.txt
#   inflating: content/labels/886.txt
#   inflating: content/labels/101.txt
#   inflating: content/labels/2137.txt
#   inflating: content/labels/1231.txt
#   inflating: content/labels/364.txt
#   inflating: content/labels/3348.txt
#   inflating: content/labels/194.txt
#   inflating: content/labels/3453.txt
#   inflating: content/labels/568.txt
#   inflating: content/labels/2442.txt
#   inflating: content/labels/203.txt
#   inflating: content/labels/936.txt
#   inflating: content/labels/2340.txt
#   inflating: content/labels/2947.txt
#   inflating: content/labels/113.txt
#   inflating: content/labels/2070.txt
#   inflating: content/labels/1327.txt
#   inflating: content/labels/1510.txt
#   inflating: content/labels/1020.txt
#   inflating: content/labels/1823.txt
#   inflating: content/labels/2177.txt
#   inflating: content/labels/3175.txt
#   inflating: content/labels/2599.txt
#   inflating: content/labels/3406.txt
#   inflating: content/labels/1583.txt
#   inflating: content/labels/48.txt
#   inflating: content/labels/27.txt
#   inflating: content/labels/1715.txt
#   inflating: content/labels/1172.txt
#   inflating: content/labels/1961.txt
#   inflating: content/labels/2328.txt
#   inflating: content/labels/1170.txt
#   inflating: content/labels/3002.txt
#   inflating: content/labels/3279.txt
#   inflating: content/labels/2926.txt
#   inflating: content/labels/1514.txt
#   inflating: content/labels/264.txt
#   inflating: content/labels/2278.txt
#   inflating: content/labels/316.txt
#   inflating: content/labels/1220.txt
#   inflating: content/labels/1662.txt
#   inflating: content/labels/921.txt
#   inflating: content/labels/2941.txt
#   inflating: content/labels/2252.txt
#   inflating: content/labels/695.txt
#   inflating: content/labels/1644.txt
#   inflating: content/labels/2344.txt
#   inflating: content/labels/2151.txt
#   inflating: content/labels/484.txt
#   inflating: content/labels/3496.txt
#   inflating: content/labels/3241.txt
#   inflating: content/labels/2643.txt
#   inflating: content/labels/2974.txt
#   inflating: content/labels/2786.txt
#   inflating: content/labels/2547.txt
#   inflating: content/labels/1071.txt
#   inflating: content/labels/987.txt
#   inflating: content/labels/2578.txt
#   inflating: content/labels/2265.txt
#   inflating: content/labels/949.txt
#   inflating: content/labels/586.txt
#   inflating: content/labels/1548.txt
#   inflating: content/labels/915.txt
#   inflating: content/labels/1628.txt
#   inflating: content/labels/762.txt
#   inflating: content/labels/2538.txt
#   inflating: content/labels/353.txt
#   inflating: content/labels/3286.txt
#   inflating: content/labels/2636.txt
#   inflating: content/labels/2874.txt
#   inflating: content/labels/292.txt
#   inflating: content/labels/622.txt
#   inflating: content/labels/499.txt
#   inflating: content/labels/1.txt
#   inflating: content/labels/2148.txt
#   inflating: content/labels/1211.txt
#   inflating: content/labels/225.txt
#   inflating: content/labels/582.txt
#   inflating: content/labels/3439.txt
#   inflating: content/labels/3224.txt
#   inflating: content/labels/2592.txt
#   inflating: content/labels/2900.txt
#   inflating: content/labels/1023.txt
#   inflating: content/labels/2204.txt
#   inflating: content/labels/2893.txt
#   inflating: content/labels/403.txt
#   inflating: content/labels/475.txt
#   inflating: content/labels/2035.txt
#   inflating: content/labels/1918.txt
#   inflating: content/labels/639.txt
#   inflating: content/labels/3210.txt
#   inflating: content/labels/873.txt
#   inflating: content/labels/2881.txt
#   inflating: content/labels/945.txt
#   inflating: content/labels/2652.txt
#   inflating: content/labels/1365.txt
#   inflating: content/labels/38.txt
#   inflating: content/labels/2906.txt
#   inflating: content/labels/2989.txt
#   inflating: content/labels/1218.txt
#   inflating: content/labels/3524.txt
#   inflating: content/labels/393.txt
#   inflating: content/labels/2450.txt
#   inflating: content/labels/2609.txt
#   inflating: content/labels/2237.txt
#   inflating: content/labels/1156.txt
#   inflating: content/labels/1275.txt
#   inflating: content/labels/1040.txt
#   inflating: content/labels/172.txt
#   inflating: content/labels/1559.txt
#   inflating: content/labels/1926.txt
#   inflating: content/labels/2961.txt
#   inflating: content/labels/1779.txt
#   inflating: content/labels/1191.txt
#   inflating: content/labels/905.txt
#   inflating: content/labels/1931.txt
#   inflating: content/labels/3499.txt
#   inflating: content/labels/367.txt
#   inflating: content/labels/1997.txt
#   inflating: content/labels/1498.txt
#   inflating: content/labels/979.txt
#   inflating: content/labels/1952.txt
#   inflating: content/labels/2093.txt
#   inflating: content/labels/3307.txt
#   inflating: content/labels/810.txt
#   inflating: content/labels/1008.txt
#   inflating: content/labels/760.txt
#   inflating: content/labels/2954.txt
#   inflating: content/labels/103.txt
#   inflating: content/labels/1415.txt
#   inflating: content/labels/2306.txt
#   inflating: content/labels/3363.txt
#   inflating: content/labels/2817.txt
#   inflating: content/labels/2670.txt
#   inflating: content/labels/3212.txt
#   inflating: content/labels/1391.txt
#   inflating: content/labels/164.txt
#   inflating: content/labels/3191.txt
#   inflating: content/labels/1576.txt
#   inflating: content/labels/2404.txt
#   inflating: content/labels/514.txt
#   inflating: content/labels/1110.txt
#   inflating: content/labels/1995.txt
#   inflating: content/labels/2112.txt
#   inflating: content/labels/496.txt
#   inflating: content/labels/1852.txt
#   inflating: content/labels/2305.txt
#   inflating: content/labels/2910.txt
#   inflating: content/labels/1676.txt
#   inflating: content/labels/2826.txt
#   inflating: content/labels/2682.txt
#   inflating: content/labels/1816.txt
#   inflating: content/labels/1913.txt
#   inflating: content/labels/1500.txt
#   inflating: content/labels/1326.txt
#   inflating: content/labels/2465.txt
#   inflating: content/labels/1346.txt
#   inflating: content/labels/2051.txt
#   inflating: content/labels/3287.txt
#   inflating: content/labels/3022.txt
#   inflating: content/labels/2580.txt
#   inflating: content/labels/303.txt
#   inflating: content/labels/900.txt
#   inflating: content/labels/501.txt
#   inflating: content/labels/2626.txt
#   inflating: content/labels/2671.txt
#   inflating: content/labels/2367.txt
#   inflating: content/labels/1633.txt
#   inflating: content/labels/694.txt
#   inflating: content/labels/2176.txt
#   inflating: content/labels/1431.txt
#   inflating: content/labels/2585.txt
#   inflating: content/labels/3064.txt
#   inflating: content/labels/556.txt
#   inflating: content/labels/1369.txt
#   inflating: content/labels/3096.txt
#   inflating: content/labels/460.txt
#   inflating: content/labels/1227.txt
#   inflating: content/labels/3189.txt
#   inflating: content/labels/2380.txt
#   inflating: content/labels/588.txt
#   inflating: content/labels/2725.txt
#   inflating: content/labels/3004.txt
#   inflating: content/labels/1819.txt
#   inflating: content/labels/868.txt
#   inflating: content/labels/1627.txt
#   inflating: content/labels/2145.txt
#   inflating: content/labels/2292.txt
#   inflating: content/labels/3361.txt
#   inflating: content/labels/1173.txt
#   inflating: content/labels/3114.txt
#   inflating: content/labels/1745.txt
#   inflating: content/labels/77.txt
#   inflating: content/labels/1254.txt
#   inflating: content/labels/614.txt
#   inflating: content/labels/712.txt
#   inflating: content/labels/2839.txt
#   inflating: content/labels/70.txt
#   inflating: content/labels/3413.txt
#   inflating: content/labels/2207.txt
#   inflating: content/labels/2229.txt
#   inflating: content/labels/2843.txt
#   inflating: content/labels/3507.txt
#   inflating: content/labels/1520.txt
#   inflating: content/labels/2510.txt
#   inflating: content/labels/1922.txt
#   inflating: content/labels/2262.txt
#   inflating: content/labels/3027.txt
#   inflating: content/labels/1249.txt
#   inflating: content/labels/3433.txt
#   inflating: content/labels/1784.txt
#   inflating: content/labels/1833.txt
#   inflating: content/labels/785.txt
#   inflating: content/labels/536.txt
#   inflating: content/labels/2777.txt
#   inflating: content/labels/87.txt
#   inflating: content/labels/502.txt
#   inflating: content/labels/2992.txt
#   inflating: content/labels/711.txt
#   inflating: content/labels/1370.txt
#   inflating: content/labels/2755.txt
#   inflating: content/labels/333.txt
#   inflating: content/labels/2331.txt
#   inflating: content/labels/1255.txt
#   inflating: content/labels/2001.txt
#   inflating: content/labels/2714.txt
#   inflating: content/labels/72.txt
#   inflating: content/labels/835.txt
#   inflating: content/labels/0.txt
#   inflating: content/labels/2691.txt
#   inflating: content/labels/2334.txt
#   inflating: content/labels/928.txt
#   inflating: content/labels/3208.txt
#   inflating: content/labels/1259.txt
#   inflating: content/labels/2267.txt
#   inflating: content/labels/3429.txt
#   inflating: content/labels/270.txt
#   inflating: content/labels/176.txt
#   inflating: content/labels/1804.txt
#   inflating: content/labels/960.txt
#   inflating: content/labels/837.txt
#   inflating: content/labels/530.txt
#   inflating: content/labels/142.txt
#   inflating: content/labels/3261.txt
#   inflating: content/labels/706.txt
#   inflating: content/labels/1637.txt
#   inflating: content/labels/821.txt
#   inflating: content/labels/793.txt
#   inflating: content/labels/2887.txt
#   inflating: content/labels/3039.txt
#   inflating: content/labels/572.txt
#   inflating: content/labels/467.txt
#   inflating: content/labels/1632.txt
#   inflating: content/labels/551.txt
#   inflating: content/labels/2615.txt
#   inflating: content/labels/3308.txt
#   inflating: content/labels/1711.txt
#   inflating: content/labels/1730.txt
#   inflating: content/labels/286.txt
#   inflating: content/labels/954.txt
#   inflating: content/labels/616.txt
#   inflating: content/labels/2182.txt
#   inflating: content/labels/1080.txt
#   inflating: content/labels/3216.txt
#   inflating: content/labels/2245.txt
#   inflating: content/labels/338.txt
#   inflating: content/labels/2202.txt
#   inflating: content/labels/2519.txt
#   inflating: content/labels/2659.txt
#   inflating: content/labels/1859.txt
#   inflating: content/labels/531.txt
#   inflating: content/labels/424.txt
#   inflating: content/labels/2840.txt
#   inflating: content/labels/1869.txt
#   inflating: content/labels/1991.txt
#   inflating: content/labels/647.txt
#   inflating: content/labels/1214.txt
#   inflating: content/labels/841.txt
#   inflating: content/labels/437.txt
#   inflating: content/labels/1180.txt
#   inflating: content/labels/574.txt
#   inflating: content/labels/2847.txt
#   inflating: content/labels/1668.txt
#   inflating: content/labels/2518.txt
#   inflating: content/labels/446.txt
#   inflating: content/labels/529.txt
#   inflating: content/labels/3068.txt
#   inflating: content/labels/774.txt
#   inflating: content/labels/2097.txt
#   inflating: content/labels/1294.txt
#   inflating: content/labels/3265.txt
#   inflating: content/labels/344.txt
#   inflating: content/labels/570.txt
#   inflating: content/labels/3339.txt
#   inflating: content/labels/1611.txt
#   inflating: content/labels/2374.txt
#   inflating: content/labels/3139.txt
#   inflating: content/labels/2707.txt
#   inflating: content/labels/1809.txt
#   inflating: content/labels/2790.txt
#   inflating: content/labels/498.txt
#   inflating: content/labels/2101.txt
#   inflating: content/labels/352.txt
#   inflating: content/labels/343.txt
#   inflating: content/labels/3497.txt
#   inflating: content/labels/242.txt
#   inflating: content/labels/764.txt
#   inflating: content/labels/1114.txt
#   inflating: content/labels/665.txt
#   inflating: content/labels/394.txt
#   inflating: content/labels/1024.txt
#   inflating: content/labels/3233.txt
#   inflating: content/labels/427.txt
#   inflating: content/labels/1063.txt
#   inflating: content/labels/3267.txt
#   inflating: content/labels/3124.txt
#   inflating: content/labels/2089.txt
#   inflating: content/labels/2150.txt
#   inflating: content/labels/842.txt
#   inflating: content/labels/2654.txt
#   inflating: content/labels/3281.txt
#   inflating: content/labels/2248.txt
#   inflating: content/labels/747.txt
#   inflating: content/labels/3402.txt
#   inflating: content/labels/1494.txt
#   inflating: content/labels/1261.txt
#   inflating: content/labels/684.txt
#   inflating: content/labels/1725.txt
#   inflating: content/labels/796.txt
#   inflating: content/labels/3492.txt
#   inflating: content/labels/3016.txt
#   inflating: content/labels/755.txt
#   inflating: content/labels/2975.txt
#   inflating: content/labels/1845.txt
#   inflating: content/labels/1193.txt
#   inflating: content/labels/3101.txt
#   inflating: content/labels/594.txt
#   inflating: content/labels/2624.txt
#   inflating: content/labels/3012.txt
#   inflating: content/labels/3057.txt
#   inflating: content/labels/1027.txt
#   inflating: content/labels/1215.txt
#   inflating: content/labels/3176.txt
#   inflating: content/labels/1412.txt
#   inflating: content/labels/83.txt
#   inflating: content/labels/2409.txt
#   inflating: content/labels/2156.txt
#   inflating: content/labels/697.txt
#   inflating: content/labels/628.txt
#   inflating: content/labels/372.txt
#   inflating: content/labels/1953.txt
#   inflating: content/labels/1565.txt
#   inflating: content/labels/1963.txt
#   inflating: content/labels/2095.txt
#   inflating: content/labels/2556.txt
#   inflating: content/labels/1534.txt
#   inflating: content/labels/2492.txt
#   inflating: content/labels/2825.txt
#   inflating: content/labels/604.txt
#   inflating: content/labels/2515.txt
#   inflating: content/labels/1141.txt
#   inflating: content/labels/443.txt
#   inflating: content/labels/2088.txt
#   inflating: content/labels/1928.txt
#   inflating: content/labels/97.txt
#   inflating: content/labels/1942.txt
#   inflating: content/labels/477.txt
#   inflating: content/labels/1722.txt
#   inflating: content/labels/1003.txt
#   inflating: content/labels/2803.txt
#   inflating: content/labels/3332.txt
#   inflating: content/labels/1888.txt
#   inflating: content/labels/749.txt
#   inflating: content/labels/1653.txt
#   inflating: content/labels/2489.txt
#   inflating: content/labels/1776.txt
#   inflating: content/labels/2200.txt
#   inflating: content/labels/1217.txt
#   inflating: content/labels/1800.txt
#   inflating: content/labels/1119.txt
#   inflating: content/labels/461.txt
#   inflating: content/labels/1968.txt
#   inflating: content/labels/1183.txt
#   inflating: content/labels/1683.txt
#   inflating: content/labels/2933.txt
#   inflating: content/labels/2620.txt
#   inflating: content/labels/893.txt
#   inflating: content/labels/2785.txt
#   inflating: content/labels/722.txt
#   inflating: content/labels/725.txt
#   inflating: content/labels/3540.txt
#   inflating: content/labels/2797.txt
#   inflating: content/labels/3019.txt
#   inflating: content/labels/2355.txt
#   inflating: content/labels/2315.txt
#   inflating: content/labels/2079.txt
#   inflating: content/labels/3290.txt
#   inflating: content/labels/88.txt
#   inflating: content/labels/1620.txt
#   inflating: content/labels/3262.txt
#   inflating: content/labels/2774.txt
#   inflating: content/labels/2011.txt
#   inflating: content/labels/1606.txt
#   inflating: content/labels/1592.txt
#   inflating: content/labels/581.txt
#   inflating: content/labels/596.txt
#   inflating: content/labels/200.txt
#   inflating: content/labels/1009.txt
#   inflating: content/labels/994.txt
#   inflating: content/labels/1164.txt
#   inflating: content/labels/280.txt
#   inflating: content/labels/1082.txt
#   inflating: content/labels/3340.txt
#   inflating: content/labels/3347.txt
#   inflating: content/labels/710.txt
#   inflating: content/labels/1971.txt
#   inflating: content/labels/1307.txt
#   inflating: content/labels/1754.txt
#   inflating: content/labels/470.txt
#   inflating: content/labels/2836.txt
#   inflating: content/labels/2931.txt
#   inflating: content/labels/1476.txt
#   inflating: content/labels/125.txt
#   inflating: content/labels/2424.txt
#   inflating: content/labels/3397.txt
#   inflating: content/labels/2026.txt
#   inflating: content/labels/2313.txt
#   inflating: content/labels/790.txt
#   inflating: content/labels/1286.txt
#   inflating: content/labels/3130.txt
#   inflating: content/labels/2506.txt
#   inflating: content/labels/371.txt
#   inflating: content/labels/1788.txt
#   inflating: content/labels/2052.txt
#   inflating: content/labels/929.txt
#   inflating: content/labels/1980.txt
#   inflating: content/labels/2140.txt
#   inflating: content/labels/3010.txt
#   inflating: content/labels/3028.txt
#   inflating: content/labels/3080.txt
#   inflating: content/labels/3445.txt
#   inflating: content/labels/355.txt
#   inflating: content/labels/1045.txt
#   inflating: content/labels/2157.txt
#   inflating: content/labels/34.txt
#   inflating: content/labels/18.txt
#   inflating: content/labels/2955.txt
#   inflating: content/labels/2319.txt
#   inflating: content/labels/1256.txt
#   inflating: content/labels/1780.txt
#   inflating: content/labels/2474.txt
#   inflating: content/labels/867.txt
#   inflating: content/labels/769.txt
#   inflating: content/labels/1669.txt
#   inflating: content/labels/2988.txt
#   inflating: content/labels/1284.txt
#   inflating: content/labels/891.txt
#   inflating: content/labels/335.txt
#   inflating: content/labels/1351.txt
#   inflating: content/labels/3493.txt
#   inflating: content/labels/1447.txt
#   inflating: content/labels/2071.txt
#   inflating: content/labels/79.txt
#   inflating: content/labels/1216.txt
#   inflating: content/labels/547.txt
#   inflating: content/labels/3014.txt
#   inflating: content/labels/1550.txt
#   inflating: content/labels/2727.txt
#   inflating: content/labels/1536.txt
#   inflating: content/labels/1848.txt
#   inflating: content/labels/942.txt
#   inflating: content/labels/3121.txt
#   inflating: content/labels/2441.txt
#   inflating: content/labels/2860.txt
#   inflating: content/labels/1727.txt
#   inflating: content/labels/927.txt
#   inflating: content/labels/25.txt
#   inflating: content/labels/2731.txt
#   inflating: content/labels/918.txt
#   inflating: content/labels/3270.txt
#   inflating: content/labels/2087.txt
#   inflating: content/labels/1000.txt
#   inflating: content/labels/2695.txt
#   inflating: content/labels/998.txt
#   inflating: content/labels/1168.txt
# ...
#   inflating: content/labels/2284.txt
#   inflating: content/labels/3321.txt
#   inflating: content/labels/1186.txt
#   inflating: content/labels/2917.txt
#   inflating: content/labels/1861.txt
#   inflating: content/labels/2233.txt
#   inflating: content/labels/2876.txt
#   inflating: content/labels/1342.txt
#   inflating: content/labels/626.txt
#   inflating: content/labels/1648.txt
#   inflating: content/labels/3327.txt
#   inflating: content/labels/2030.txt
#   inflating: content/labels/151.txt
#   inflating: content/labels/2080.txt
#   inflating: content/labels/855.txt
#   inflating: content/labels/3448.txt
#   inflating: content/labels/2824.txt
#   inflating: content/labels/2386.txt
#   inflating: content/labels/1966.txt
#   inflating: content/labels/3548.txt
#   inflating: content/labels/241.txt
#   inflating: content/labels/2647.txt
#   inflating: content/labels/595.txt
#   inflating: content/labels/2357.txt
#   inflating: content/labels/1283.txt
#   inflating: content/labels/1178.txt
#   inflating: content/labels/2905.txt
#   inflating: content/labels/1022.txt
#   inflating: content/labels/2501.txt
#   inflating: content/labels/2435.txt
#   inflating: content/labels/3230.txt
#   inflating: content/labels/2511.txt
#   inflating: content/labels/3461.txt
#   inflating: content/labels/3384.txt
#   inflating: content/labels/1324.txt
#   inflating: content/labels/2283.txt
#   inflating: content/labels/1894.txt
#   inflating: content/labels/1423.txt
#   inflating: content/labels/256.txt
#   inflating: content/labels/33.txt
#   inflating: content/labels/3277.txt
#   inflating: content/labels/539.txt
#   inflating: content/labels/3377.txt
#   inflating: content/labels/1203.txt
#   inflating: content/labels/3035.txt
#   inflating: content/labels/3527.txt
#   inflating: content/labels/445.txt
#   inflating: content/labels/7.txt
#   inflating: content/labels/870.txt
#   inflating: content/labels/2057.txt
#   inflating: content/labels/1767.txt
#   inflating: content/labels/3249.txt
#   inflating: content/labels/52.txt
#   inflating: content/labels/1629.txt
#   inflating: content/labels/985.txt
#   inflating: content/labels/1219.txt
#   inflating: content/labels/828.txt
#   inflating: content/labels/2403.txt
#   inflating: content/labels/1855.txt
#   inflating: content/labels/268.txt
#   inflating: content/labels/2113.txt
#   inflating: content/labels/3392.txt
#   inflating: content/labels/631.txt
#   inflating: content/labels/1882.txt
#   inflating: content/labels/3537.txt
#   inflating: content/labels/408.txt
#   inflating: content/labels/1830.txt
#   inflating: content/labels/1758.txt
#   inflating: content/labels/1801.txt
#   inflating: content/labels/2075.txt
#   inflating: content/labels/311.txt
#   inflating: content/labels/538.txt
#   inflating: content/labels/2793.txt
#   inflating: content/labels/2019.txt
#   inflating: content/labels/746.txt
#   inflating: content/labels/1844.txt
#   inflating: content/labels/2377.txt
#   inflating: content/labels/3123.txt
#   inflating: content/labels/1986.txt
#   inflating: content/labels/3009.txt
#   inflating: content/labels/68.txt
#   inflating: content/labels/1841.txt
#   inflating: content/labels/3264.txt
#   inflating: content/labels/3328.txt
#   inflating: content/labels/2165.txt
#   inflating: content/labels/2268.txt
#   inflating: content/labels/2808.txt
#   inflating: content/labels/1840.txt
#   inflating: content/labels/3199.txt
#   inflating: content/labels/1580.txt
#   inflating: content/labels/1977.txt
#   inflating: content/labels/418.txt
#   inflating: content/labels/3336.txt
#   inflating: content/labels/957.txt
#   inflating: content/labels/169.txt
#   inflating: content/labels/448.txt
#   inflating: content/labels/545.txt
#   inflating: content/labels/878.txt
#   inflating: content/labels/1281.txt
#   inflating: content/labels/417.txt
#   inflating: content/labels/2687.txt
#   inflating: content/labels/1394.txt
#   inflating: content/labels/1176.txt
#   inflating: content/labels/3034.txt
#   inflating: content/labels/651.txt
#   inflating: content/labels/1416.txt
#   inflating: content/labels/3529.txt
#   inflating: content/labels/2295.txt
#   inflating: content/labels/1177.txt
#   inflating: content/labels/2429.txt
#   inflating: content/labels/839.txt
#   inflating: content/labels/5.txt
#   inflating: content/labels/3480.txt
#   inflating: content/labels/3232.txt
#   inflating: content/labels/302.txt
#   inflating: content/labels/1597.txt
#   inflating: content/labels/1355.txt
#   inflating: content/labels/2990.txt
#   inflating: content/labels/922.txt
#   inflating: content/labels/1956.txt
#   inflating: content/labels/666.txt
#   inflating: content/labels/2689.txt
#   inflating: content/labels/1269.txt
#   inflating: content/labels/1088.txt
#   inflating: content/labels/1051.txt
#   inflating: content/labels/1493.txt
#   inflating: content/labels/1542.txt
#   inflating: content/labels/1684.txt
#   inflating: content/labels/1842.txt
#   inflating: content/labels/3116.txt
#   inflating: content/labels/1011.txt
#   inflating: content/labels/363.txt
#   inflating: content/labels/563.txt
#   inflating: content/labels/3065.txt
#   inflating: content/labels/1703.txt
#   inflating: content/labels/55.txt
#   inflating: content/labels/3475.txt
#   inflating: content/labels/2832.txt
#   inflating: content/labels/1710.txt
#   inflating: content/labels/1739.txt
#   inflating: content/labels/736.txt
#   inflating: content/labels/136.txt
#   inflating: content/labels/3419.txt
#   inflating: content/labels/3341.txt
#   inflating: content/labels/2765.txt
#   inflating: content/labels/462.txt
#   inflating: content/labels/2298.txt
#   inflating: content/labels/1616.txt
#   inflating: content/labels/2746.txt
#   inflating: content/labels/675.txt
#   inflating: content/labels/419.txt
#   inflating: content/labels/991.txt
#   inflating: content/labels/2269.txt
#   inflating: content/labels/287.txt
#   inflating: content/labels/3074.txt
#   inflating: content/labels/1907.txt
#   inflating: content/labels/2726.txt
#   inflating: content/labels/2605.txt
#   inflating: content/labels/174.txt
#   inflating: content/labels/2413.txt
#   inflating: content/labels/3547.txt
#   inflating: content/labels/430.txt
#   inflating: content/labels/1595.txt
#   inflating: content/labels/362.txt
#   inflating: content/labels/3051.txt
#   inflating: content/labels/1205.txt
#   inflating: content/labels/2976.txt
#   inflating: content/labels/2038.txt
#   inflating: content/labels/2966.txt
#   inflating: content/labels/2183.txt
#   inflating: content/labels/3485.txt
#   inflating: content/labels/3108.txt
#   inflating: content/labels/2125.txt
#   inflating: content/labels/2133.txt
#   inflating: content/labels/1587.txt
#   inflating: content/labels/3425.txt
#   inflating: content/labels/3338.txt
#   inflating: content/labels/726.txt
#   inflating: content/labels/550.txt
#   inflating: content/labels/1887.txt
#   inflating: content/labels/1232.txt
#   inflating: content/labels/517.txt
#   inflating: content/labels/2883.txt
#   inflating: content/labels/587.txt
#   inflating: content/labels/2535.txt
#   inflating: content/labels/943.txt
#   inflating: content/labels/189.txt
#   inflating: content/labels/2439.txt
#   inflating: content/labels/340.txt
#   inflating: content/labels/252.txt
#   inflating: content/labels/1310.txt
#   inflating: content/labels/964.txt
#   inflating: content/labels/3109.txt
#   inflating: content/labels/2381.txt
#   inflating: content/labels/223.txt
#   inflating: content/labels/1964.txt
#   inflating: content/labels/1590.txt
#   inflating: content/labels/1012.txt
#   inflating: content/labels/2522.txt
#   inflating: content/labels/1509.txt
#   inflating: content/labels/69.txt
#   inflating: content/labels/1701.txt
#   inflating: content/labels/2915.txt
#   inflating: content/labels/2230.txt
#   inflating: content/labels/524.txt
#   inflating: content/labels/589.txt
#   inflating: content/labels/274.txt
#   inflating: content/labels/767.txt
#   inflating: content/labels/1693.txt
#   inflating: content/labels/2713.txt
#   inflating: content/labels/2549.txt
#   inflating: content/labels/3349.txt
#   inflating: content/labels/2595.txt
#   inflating: content/labels/211.txt
#   inflating: content/labels/2033.txt
#   inflating: content/labels/2037.txt
#   inflating: content/labels/2114.txt
#   inflating: content/labels/933.txt
#   inflating: content/labels/2716.txt
#   inflating: content/labels/1626.txt
#   inflating: content/labels/2446.txt
#   inflating: content/labels/681.txt
#   inflating: content/labels/3196.txt
#   inflating: content/labels/2665.txt
#   inflating: content/labels/1366.txt
#   inflating: content/labels/2153.txt
#   inflating: content/labels/1960.txt
#   inflating: content/labels/119.txt
#   inflating: content/labels/962.txt
#   inflating: content/labels/2420.txt
#   inflating: content/labels/1712.txt
#   inflating: content/labels/368.txt
#   inflating: content/labels/2012.txt
#   inflating: content/labels/334.txt
#   inflating: content/labels/1485.txt
#   inflating: content/labels/1567.txt
#   inflating: content/labels/977.txt
#   inflating: content/labels/1400.txt
#   inflating: content/labels/3244.txt
#   inflating: content/labels/2908.txt
#   inflating: content/labels/1289.txt
#   inflating: content/labels/2757.txt
#   inflating: content/labels/1818.txt
#   inflating: content/labels/2978.txt
#   inflating: content/labels/1244.txt
#   inflating: content/labels/3248.txt
#   inflating: content/labels/2500.txt
#   inflating: content/labels/2307.txt
#   inflating: content/labels/2587.txt
#   inflating: content/labels/671.txt
#   inflating: content/labels/1783.txt
#   inflating: content/labels/1263.txt
#   inflating: content/labels/3169.txt
#   inflating: content/labels/1489.txt
#   inflating: content/labels/663.txt
#   inflating: content/labels/1458.txt
#   inflating: content/labels/3531.txt
#   inflating: content/labels/535.txt
#   inflating: content/labels/1951.txt
#   inflating: content/labels/2008.txt
#   inflating: content/labels/486.txt
#   inflating: content/labels/323.txt
#   inflating: content/labels/659.txt
#   inflating: content/labels/1821.txt
#   inflating: content/labels/104.txt
#   inflating: content/labels/3222.txt
#   inflating: content/labels/2485.txt
#   inflating: content/labels/432.txt
#   inflating: content/labels/1171.txt
#   inflating: content/labels/2523.txt
#   inflating: content/labels/2526.txt
#   inflating: content/labels/2322.txt
#   inflating: content/labels/1513.txt
#   inflating: content/labels/396.txt
#   inflating: content/labels/2949.txt
#   inflating: content/labels/1622.txt
#   inflating: content/labels/2226.txt
#   inflating: content/labels/3469.txt
#   inflating: content/labels/617.txt
#   inflating: content/labels/261.txt
#   inflating: content/labels/140.txt
#   inflating: content/labels/730.txt
#   inflating: content/labels/575.txt
#   inflating: content/labels/1880.txt
#   inflating: content/labels/2895.txt
#   inflating: content/labels/3076.txt
#   inflating: content/labels/3107.txt
#   inflating: content/labels/1143.txt
#   inflating: content/labels/162.txt
#   inflating: content/labels/1999.txt
#   inflating: content/labels/36.txt
#   inflating: content/labels/212.txt
#   inflating: content/labels/2866.txt
#   inflating: content/labels/701.txt
#   inflating: content/labels/3459.txt
#   inflating: content/labels/2452.txt
#   inflating: content/labels/1018.txt
#   inflating: content/labels/2115.txt
#   inflating: content/labels/454.txt
#   inflating: content/labels/2710.txt
#   inflating: content/labels/3229.txt
#   inflating: content/labels/1764.txt
#   inflating: content/labels/1505.txt
#   inflating: content/labels/1268.txt
#   inflating: content/labels/322.txt
#   inflating: content/labels/3404.txt
#   inflating: content/labels/1873.txt
#   inflating: content/labels/2631.txt
#   inflating: content/labels/2451.txt
#   inflating: content/labels/13.txt
#   inflating: content/labels/624.txt
#   inflating: content/labels/3324.txt
#   inflating: content/labels/2661.txt
#   inflating: content/labels/3153.txt
#   inflating: content/labels/42.txt
#   inflating: content/labels/3344.txt
#   inflating: content/labels/288.txt
#   inflating: content/labels/602.txt
#   inflating: content/labels/339.txt
#   inflating: content/labels/3530.txt
#   inflating: content/labels/1007.txt
#   inflating: content/labels/216.txt
#   inflating: content/labels/160.txt
#   inflating: content/labels/453.txt
#   inflating: content/labels/2867.txt
#   inflating: content/labels/3394.txt
#   inflating: content/labels/2104.txt
#   inflating: content/labels/1199.txt
#   inflating: content/labels/215.txt
#   inflating: content/labels/2623.txt
#   inflating: content/labels/3246.txt
#   inflating: content/labels/1109.txt
#   inflating: content/labels/2543.txt
#   inflating: content/labels/2010.txt
#   inflating: content/labels/123.txt
#   inflating: content/labels/693.txt
#   inflating: content/labels/2792.txt
#   inflating: content/labels/175.txt
#   inflating: content/labels/660.txt
#   inflating: content/labels/1403.txt
#   inflating: content/labels/1131.txt
#   inflating: content/labels/3389.txt
#   inflating: content/labels/3320.txt
#   inflating: content/labels/1041.txt
#   inflating: content/labels/3128.txt
#   inflating: content/labels/1691.txt
#   inflating: content/labels/1210.txt
#   inflating: content/labels/772.txt
#   inflating: content/labels/3173.txt
#   inflating: content/labels/689.txt
#   inflating: content/labels/166.txt
#   inflating: content/labels/3498.txt
#   inflating: content/labels/2360.txt
#   inflating: content/labels/2971.txt
#   inflating: content/labels/2930.txt
#   inflating: content/labels/1314.txt
#   inflating: content/labels/3476.txt
#   inflating: content/labels/2828.txt
#   inflating: content/labels/2246.txt
#   inflating: content/labels/127.txt
#   inflating: content/labels/2300.txt
#   inflating: content/labels/3504.txt
#   inflating: content/labels/3271.txt
#   inflating: content/labels/2249.txt
#   inflating: content/labels/598.txt
#   inflating: content/labels/1828.txt
#   inflating: content/labels/1547.txt
#   inflating: content/labels/244.txt
#   inflating: content/labels/3390.txt
#   inflating: content/labels/981.txt
#   inflating: content/labels/1539.txt
#   inflating: content/labels/3122.txt
#   inflating: content/labels/3256.txt
#   inflating: content/labels/1392.txt
#   inflating: content/labels/2353.txt
#   inflating: content/labels/2393.txt
#   inflating: content/labels/2457.txt
#   inflating: content/labels/399.txt
#   inflating: content/labels/1879.txt
#   inflating: content/labels/1442.txt
#   inflating: content/labels/1658.txt
#   inflating: content/labels/468.txt
#   inflating: content/labels/361.txt
#   inflating: content/labels/546.txt
#   inflating: content/labels/3126.txt
#   inflating: content/labels/3254.txt
#   inflating: content/labels/1586.txt
#   inflating: content/labels/32.txt
#   inflating: content/labels/3140.txt
#   inflating: content/labels/1478.txt
#   inflating: content/labels/2835.txt
#   inflating: content/labels/1402.txt
#   inflating: content/labels/1043.txt
#   inflating: content/labels/2929.txt
#   inflating: content/labels/227.txt
#   inflating: content/labels/3395.txt
#   inflating: content/labels/925.txt
#   inflating: content/labels/2667.txt
#   inflating: content/labels/2651.txt
#   inflating: content/labels/4.txt
#   inflating: content/labels/2970.txt
#   inflating: content/labels/1338.txt
#   inflating: content/labels/1086.txt
#   inflating: content/labels/1026.txt
#   inflating: content/labels/2534.txt
#   inflating: content/labels/3071.txt
#   inflating: content/labels/956.txt
#   inflating: content/labels/2907.txt
#   inflating: content/labels/2235.txt
#   inflating: content/labels/742.txt
#   inflating: content/labels/2427.txt
#   inflating: content/labels/1835.txt
#   inflating: content/labels/548.txt

# %%
# !unzip /content/drive/MyDrive/CS5242/images.zip
# Out:
# Archive:  /content/drive/MyDrive/CS5242/images.zip
#    creating: images/
#    creating: content/images/
#   inflating: content/images/1446.png
#   inflating: content/images/3486.png
#   inflating: content/images/931.png
#   inflating: content/images/978.png
#   inflating: content/images/1519.png
#   inflating: content/images/2666.png
#   inflating: content/images/1443.png
#   inflating: content/images/1819.png
#   inflating: content/images/2802.png
#   inflating: content/images/596.png
#   inflating: content/images/21.JPG
#   inflating: content/images/3394.png
#   inflating: content/images/2901.png
#   inflating: content/images/815.png
#   inflating: content/images/1323.png
#   inflating: content/images/2932.png
#   inflating: content/images/1968.png
#   inflating: content/images/3388.png
#   inflating: content/images/2614.png
#   inflating: content/images/2282.png
#   inflating: content/images/3056.png
#   inflating: content/images/727.png
#   inflating: content/images/2608.png
#   inflating: content/images/1862.png
#   inflating: content/images/2685.png
#   inflating: content/images/1302.png
#   inflating: content/images/3469.png
#   inflating: content/images/2073.png
#   inflating: content/images/826.png
#   inflating: content/images/1187.png
#   inflating: content/images/2873.png
#   inflating: content/images/1824.png
#   inflating: content/images/3322.png
#   inflating: content/images/2830.png
#   inflating: content/images/3285.png
#   inflating: content/images/3287.png
#   inflating: content/images/469.png
#   inflating: content/images/2052.png
#   inflating: content/images/259.jpg
#   inflating: content/images/2834.png
#   inflating: content/images/244.jpg
#   inflating: content/images/2661.png
#   inflating: content/images/720.png
#   inflating: content/images/2727.png
#   inflating: content/images/613.png
#   inflating: content/images/3182.png
#   inflating: content/images/1692.png
#   inflating: content/images/2397.png
#   inflating: content/images/3033.png
#   inflating: content/images/348.jpg
#   inflating: content/images/429.png
#   inflating: content/images/3446.png
#   inflating: content/images/2779.png
#   inflating: content/images/733.png
#   inflating: content/images/1521.png
#   inflating: content/images/2573.png
#   inflating: content/images/758.png
#   inflating: content/images/2822.png
#   inflating: content/images/3521.png
#   inflating: content/images/2012.png
#   inflating: content/images/2360.png
#   inflating: content/images/1267.png
#   inflating: content/images/685.png
#   inflating: content/images/1383.png
#   inflating: content/images/1985.png
#   inflating: content/images/67.jpg
#   inflating: content/images/1577.png
#   inflating: content/images/1373.png
#   inflating: content/images/191.jpg
#   inflating: content/images/1536.png
#   inflating: content/images/1015.png
#   inflating: content/images/1017.png
#   inflating: content/images/439.png
#   inflating: content/images/3045.png
#   inflating: content/images/137.JPG
#   inflating: content/images/3435.png
#   inflating: content/images/178.jpg
#   inflating: content/images/33.jpg
#   inflating: content/images/1245.png
#   inflating: content/images/1928.png
#   inflating: content/images/3152.png
#   inflating: content/images/27.jpg
#   inflating: content/images/1089.png
#   inflating: content/images/533.png
#   inflating: content/images/2997.png
#   inflating: content/images/2879.png
#   inflating: content/images/392.png
#   inflating: content/images/1273.png
#   inflating: content/images/1037.png
#   inflating: content/images/1545.png
#   inflating: content/images/749.png
#   inflating: content/images/799.png
#   inflating: content/images/1050.png
#   inflating: content/images/1722.png
#   inflating: content/images/108.jpg
#   inflating: content/images/367.png
#   inflating: content/images/2799.png
#   inflating: content/images/142.jpg
#   inflating: content/images/112.jpg
#   inflating: content/images/2201.png
#   inflating: content/images/1014.png
#   inflating: content/images/1611.png
#   inflating: content/images/3422.png
#   inflating: content/images/654.png
#   inflating: content/images/274.JPG
#   inflating: content/images/2122.png
#   inflating: content/images/2731.png
#   inflating: content/images/222.jpg
#   inflating: content/images/1007.png
#   inflating: content/images/2362.png
#   inflating: content/images/219.jpg
#   inflating: content/images/655.png
#   inflating: content/images/2937.png
#   inflating: content/images/2268.png
#   inflating: content/images/3133.png
#   inflating: content/images/3397.png
#   inflating: content/images/2776.png
#   inflating: content/images/2639.png
#   inflating: content/images/3063.png
#   inflating: content/images/3503.png
#   inflating: content/images/2933.png
#   inflating: content/images/1523.png
#   inflating: content/images/1497.png
#   inflating: content/images/751.png
#   inflating: content/images/2099.png
#   inflating: content/images/2400.png
#   inflating: content/images/2935.png
#   inflating: content/images/2541.png
#   inflating: content/images/2013.png
#   inflating: content/images/436.png
#   inflating: content/images/1191.png
#   inflating: content/images/344.jpg
#   inflating: content/images/2328.png
#   inflating: content/images/1009.png
#   inflating: content/images/1096.png
#   inflating: content/images/3124.png
#   inflating: content/images/2470.png
#   inflating: content/images/2654.png
#   inflating: content/images/553.png
#   inflating: content/images/390.png
#   inflating: content/images/1382.png
#   inflating: content/images/2187.png
#   inflating: content/images/237.jpg
#   inflating: content/images/774.png
#   inflating: content/images/2386.png
#   inflating: content/images/2741.png
#   inflating: content/images/643.png
#   inflating: content/images/1291.png
#   inflating: content/images/3527.png
#   inflating: content/images/1242.png
#   inflating: content/images/1025.png
#   inflating: content/images/3468.png
#   inflating: content/images/1474.png
#   inflating: content/images/261.jpg
#   inflating: content/images/1566.png
#   inflating: content/images/1666.png
#   inflating: content/images/711.png
#   inflating: content/images/2492.png
#   inflating: content/images/2864.png
#   inflating: content/images/723.png
#   inflating: content/images/2877.png
#   inflating: content/images/2701.png
#   inflating: content/images/1419.png
#   inflating: content/images/741.png
#   inflating: content/images/3196.png
#   inflating: content/images/1462.png
#   inflating: content/images/1016.png
#   inflating: content/images/1799.png
#   inflating: content/images/772.png
#   inflating: content/images/1463.png
#   inflating: content/images/1609.png
#   inflating: content/images/858.png
#   inflating: content/images/2310.png
#   inflating: content/images/1838.png
#   inflating: content/images/2487.png
#   inflating: content/images/689.png
#   inflating: content/images/3412.png
#   inflating: content/images/1031.png
#   inflating: content/images/639.png
#   inflating: content/images/3533.png
#   inflating: content/images/1234.png
#   inflating: content/images/462.png
#   inflating: content/images/3379.png
#   inflating: content/images/1733.png
#   inflating: content/images/3399.png
#   inflating: content/images/1332.png
#   inflating: content/images/1624.png
#   inflating: content/images/811.png
#   inflating: content/images/936.png
#   inflating: content/images/1406.png
#   inflating: content/images/1982.png
#   inflating: content/images/3261.png
#   inflating: content/images/1674.png
#   inflating: content/images/2655.png
#   inflating: content/images/2819.png
#   inflating: content/images/1331.png
#   inflating: content/images/3075.png
#   inflating: content/images/2339.png
#   inflating: content/images/3517.png
#   inflating: content/images/601.png
#   inflating: content/images/3210.png
#   inflating: content/images/2966.png
#   inflating: content/images/1384.png
#   inflating: content/images/568.png
#   inflating: content/images/172.jpg
#   inflating: content/images/779.png
#   inflating: content/images/1983.png
#   inflating: content/images/1831.png
#   inflating: content/images/3421.png
#   inflating: content/images/3117.png
#   inflating: content/images/518.png
#   inflating: content/images/3267.png
#   inflating: content/images/3429.png
#   inflating: content/images/1619.png
#   inflating: content/images/3113.png
#   inflating: content/images/3282.png
#   inflating: content/images/2348.png
#   inflating: content/images/2642.png
#   inflating: content/images/2843.png
#   inflating: content/images/2174.png
#   inflating: content/images/2426.png
#   inflating: content/images/3482.png
#   inflating: content/images/171.jpg
#   inflating: content/images/1358.png
#   inflating: content/images/1515.png
#   inflating: content/images/1986.png
#   inflating: content/images/1898.png
#   inflating: content/images/2128.png
#   inflating: content/images/1261.png
#   inflating: content/images/3391.png
#   inflating: content/images/412.png
#   inflating: content/images/2233.png
#   inflating: content/images/951.png
#   inflating: content/images/3301.png
#   inflating: content/images/2170.png
#   inflating: content/images/24.jpg
#   inflating: content/images/2227.png
#   inflating: content/images/1845.png
#   inflating: content/images/3234.png
#   inflating: content/images/693.png
#   inflating: content/images/2221.png
#   inflating: content/images/28.jpg
#   inflating: content/images/3015.png
#   inflating: content/images/1157.png
#   inflating: content/images/1561.png
#   inflating: content/images/1770.png
#   inflating: content/images/2288.png
#   inflating: content/images/564.png
#   inflating: content/images/3329.png
#   inflating: content/images/1173.png
#   inflating: content/images/2978.png
#   inflating: content/images/2939.png
#   inflating: content/images/1642.png
#   inflating: content/images/2160.png
#   inflating: content/images/1878.png
#   inflating: content/images/560.png
#   inflating: content/images/2783.png
#   inflating: content/images/119.jpg
#   inflating: content/images/401.png
#   inflating: content/images/2341.png
#   inflating: content/images/2796.png
#   inflating: content/images/2447.png
#   inflating: content/images/871.png
#   inflating: content/images/562.png
#   inflating: content/images/2234.png
#   inflating: content/images/2633.png
#   inflating: content/images/3103.png
#   inflating: content/images/150.png
#   inflating: content/images/2490.png
#   inflating: content/images/2421.png
#   inflating: content/images/1782.png
#   inflating: content/images/2513.png
#   inflating: content/images/3180.png
#   inflating: content/images/1317.png
#   inflating: content/images/1780.png
#   inflating: content/images/2043.png
#   inflating: content/images/3066.png
#   inflating: content/images/623.png
#   inflating: content/images/3174.png
#   inflating: content/images/781.png
#   inflating: content/images/2167.png
#   inflating: content/images/2159.png
#   inflating: content/images/1818.png
#   inflating: content/images/632.png
#   inflating: content/images/158.jpg
#   inflating: content/images/2389.png
#   inflating: content/images/747.png
#   inflating: content/images/1719.png
#   inflating: content/images/3344.png
#   inflating: content/images/1112.png
#   inflating: content/images/3407.png
#   inflating: content/images/2732.png
#   inflating: content/images/948.png
#   inflating: content/images/200.jpg
#   inflating: content/images/458.png
#   inflating: content/images/1644.png
#   inflating: content/images/206.jpg
#   inflating: content/images/2064.png
#   inflating: content/images/2895.png
#   inflating: content/images/1321.png
#   inflating: content/images/1139.png
#   inflating: content/images/1916.png
#   inflating: content/images/614.png
#   inflating: content/images/2558.png
#   inflating: content/images/866.png
#   inflating: content/images/3546.png
#   inflating: content/images/3265.png
#   inflating: content/images/468.png
#   inflating: content/images/426.png
#   inflating: content/images/603.png
#   inflating: content/images/2814.png
#   inflating: content/images/413.png
#   inflating: content/images/2150.png
#   inflating: content/images/602.png
#   inflating: content/images/3498.png
#   inflating: content/images/2884.png
#   inflating: content/images/1664.png
#   inflating: content/images/2253.png
#   inflating: content/images/300.jpg
#   inflating: content/images/1806.png
#   inflating: content/images/1981.png
#   inflating: content/images/1697.png
#   inflating: content/images/1156.png
#   inflating: content/images/2820.png
#   inflating: content/images/1177.png
#   inflating: content/images/1476.png
#   inflating: content/images/391.png
#   inflating: content/images/2387.png
#   inflating: content/images/3273.png
#   inflating: content/images/3502.png
#   inflating: content/images/631.png
#   inflating: content/images/3540.png
#   inflating: content/images/1601.png
#   inflating: content/images/1504.png
#   inflating: content/images/3528.png
#   inflating: content/images/1764.png
#   inflating: content/images/1732.png
#   inflating: content/images/1502.png
#   inflating: content/images/3191.png
#   inflating: content/images/1572.png
#   inflating: content/images/1453.png
#   inflating: content/images/2489.png
#   inflating: content/images/1193.png
#   inflating: content/images/1365.png
#   inflating: content/images/3013.png
#   inflating: content/images/2368.png
#   inflating: content/images/3240.png
#   inflating: content/images/1214.png
#   inflating: content/images/1574.png
#   inflating: content/images/1322.png
#   inflating: content/images/1957.png
#   inflating: content/images/305.jpg
#   inflating: content/images/2509.png
#   inflating: content/images/1033.png
#   inflating: content/images/1699.png
#   inflating: content/images/2975.png
#   inflating: content/images/2597.png
#   inflating: content/images/2354.png
#   inflating: content/images/987.png
#   inflating: content/images/1821.png
#   inflating: content/images/1841.png
#   inflating: content/images/1145.png
#   inflating: content/images/3104.png
#   inflating: content/images/2098.png
#   inflating: content/images/1964.png
#   inflating: content/images/845.png
#   inflating: content/images/2839.png
#   inflating: content/images/1408.png
#   inflating: content/images/1591.png
#   inflating: content/images/106.jpg
#   inflating: content/images/2356.png
#   inflating: content/images/405.png
#   inflating: content/images/2026.png
#   inflating: content/images/1044.png
#   inflating: content/images/2143.png
#   inflating: content/images/123.jpg
#   inflating: content/images/876.png
#   inflating: content/images/2071.png
#   inflating: content/images/3342.png
#   inflating: content/images/194.jpg
#   inflating: content/images/577.png
#   inflating: content/images/1924.png
#   inflating: content/images/2109.png
#   inflating: content/images/3372.png
#   inflating: content/images/1546.png
#   inflating: content/images/1853.png
#   inflating: content/images/3352.png
#   inflating: content/images/2336.png
#   inflating: content/images/3415.png
#   inflating: content/images/2835.png
#   inflating: content/images/1433.png
#   inflating: content/images/3504.png
#   inflating: content/images/1787.png
#   inflating: content/images/2805.png
#   inflating: content/images/2357.png
#   inflating: content/images/2605.png
#   inflating: content/images/1579.png
#   inflating: content/images/2954.png
#   inflating: content/images/459.png
#   inflating: content/images/3349.png
#   inflating: content/images/545.png
#   inflating: content/images/3371.png
#   inflating: content/images/3034.png
#   inflating: content/images/1171.png
#   inflating: content/images/750.png
#   inflating: content/images/2753.png
#   inflating: content/images/1087.png
#   inflating: content/images/3490.png
#   inflating: content/images/2270.png
#   inflating: content/images/2317.png
#   inflating: content/images/3436.png
#   inflating: content/images/760.png
#   inflating: content/images/1394.png
#   inflating: content/images/2930.png
#   inflating: content/images/1019.png
#   inflating: content/images/1342.png
#   inflating: content/images/1512.png
#   inflating: content/images/3041.png
#   inflating: content/images/3334.png
#   inflating: content/images/1325.png
#   inflating: content/images/2766.png
#   inflating: content/images/617.png
#   inflating: content/images/327.jpg
#   inflating: content/images/358.png
#   inflating: content/images/1974.png
#   inflating: content/images/1410.png
#   inflating: content/images/138.jpg
#   inflating: content/images/93.jpg
#   inflating: content/images/381.png
#   inflating: content/images/1297.png
#   inflating: content/images/969.png
#   inflating: content/images/2752.png
#   inflating: content/images/117.jpg
#   inflating: content/images/2888.png
#   inflating: content/images/2556.png
#   inflating: content/images/1374.png
#   inflating: content/images/2372.png
#   inflating: content/images/810.png
#   inflating: content/images/61.jpg
#   inflating: content/images/2609.png
#   inflating: content/images/306.jpg
#   inflating: content/images/2545.png
#   inflating: content/images/1593.png
#   inflating: content/images/1716.png
#   inflating: content/images/2443.png
#   inflating: content/images/3347.png
#   inflating: content/images/2945.png
#   inflating: content/images/2379.png
#   inflating: content/images/3396.png
#   inflating: content/images/1863.png
#   inflating: content/images/3035.png
#   inflating: content/images/1155.png
#   inflating: content/images/3049.png
#   inflating: content/images/3302.png
#   inflating: content/images/265.jpg
#   inflating: content/images/1078.png
#   inflating: content/images/2078.png
#   inflating: content/images/3003.png
#   inflating: content/images/1866.png
#   inflating: content/images/1810.png
#   inflating: content/images/1667.png
#   inflating: content/images/2262.png
#   inflating: content/images/735.png
#   inflating: content/images/2784.png
#   inflating: content/images/2924.png
#   inflating: content/images/147.jpg
#   inflating: content/images/2644.png
#   inflating: content/images/753.png
#   inflating: content/images/1989.png
#   inflating: content/images/2827.png
#   inflating: content/images/1423.png
#   inflating: content/images/188.jpg
#   inflating: content/images/2657.png
#   inflating: content/images/667.png
#   inflating: content/images/2003.png
#   inflating: content/images/1141.png
#   inflating: content/images/2329.png
#   inflating: content/images/2302.png
#   inflating: content/images/1565.png
#   inflating: content/images/2049.png
#   inflating: content/images/1270.png
#   inflating: content/images/755.png
#   inflating: content/images/110.jpg
#   inflating: content/images/817.png
#   inflating: content/images/1921.png
#   inflating: content/images/1381.png
#   inflating: content/images/2478.png
#   inflating: content/images/2330.png
#   inflating: content/images/1250.png
#   inflating: content/images/2874.png
#   inflating: content/images/2476.png
#   inflating: content/images/1665.png
#   inflating: content/images/1200.png
#   inflating: content/images/1773.png
#   inflating: content/images/2938.png
#   inflating: content/images/2601.png
#   inflating: content/images/1590.png
#   inflating: content/images/2678.png
#   inflating: content/images/2441.png
#   inflating: content/images/1442.png
#   inflating: content/images/2965.png
#   inflating: content/images/919.png
#   inflating: content/images/1738.png
#   inflating: content/images/211.jpg
#   inflating: content/images/1104.png
#   inflating: content/images/1396.png
#   inflating: content/images/2946.png
#   inflating: content/images/2216.png
#   inflating: content/images/957.png
#   inflating: content/images/1791.png
#   inflating: content/images/2040.png
#   inflating: content/images/3501.png
#   inflating: content/images/2471.png
#   inflating: content/images/937.png
#   inflating: content/images/869.png
#   inflating: content/images/3443.png
#   inflating: content/images/2228.png
#   inflating: content/images/2089.png
#   inflating: content/images/2238.png
#   inflating: content/images/2987.png
#   inflating: content/images/183.jpg
#   inflating: content/images/3100.png
#   inflating: content/images/1525.png
#   inflating: content/images/2101.png
#   inflating: content/images/2921.png
#   inflating: content/images/159.jpg
#   inflating: content/images/980.png
#   inflating: content/images/3452.png
#   inflating: content/images/2042.png
#   inflating: content/images/814.png
#   inflating: content/images/3141.png
#   inflating: content/images/911.png
#   inflating: content/images/3225.png
#   inflating: content/images/1351.png
#   inflating: content/images/995.png
#   inflating: content/images/765.png
#   inflating: content/images/1349.png
#   inflating: content/images/308.jpg
#   inflating: content/images/1161.png
#   inflating: content/images/686.png
#   inflating: content/images/384.png
#   inflating: content/images/1850.png
#   inflating: content/images/1753.png
#   inflating: content/images/1740.png
#   inflating: content/images/3370.png
#   inflating: content/images/2912.png
#   inflating: content/images/1951.png
#   inflating: content/images/1284.png
#   inflating: content/images/742.png
#   inflating: content/images/68.jpg
#   inflating: content/images/3324.png
#   inflating: content/images/3089.png
#   inflating: content/images/2011.png
#   inflating: content/images/2264.png
#   inflating: content/images/1435.png
#   inflating: content/images/3409.png
#   inflating: content/images/1987.png
#   inflating: content/images/1218.png
#   inflating: content/images/127.jpg
#   inflating: content/images/3524.png
#   inflating: content/images/2020.png
#   inflating: content/images/1677.png
#   inflating: content/images/1391.png
#   inflating: content/images/2496.png
#   inflating: content/images/3193.png
#   inflating: content/images/268.jpg
#   inflating: content/images/2660.png
#   inflating: content/images/1110.png
#   inflating: content/images/2337.png
#   inflating: content/images/2461.png
#   inflating: content/images/3227.png
#   inflating: content/images/3007.png
#   inflating: content/images/1517.png
#   inflating: content/images/444.png
#   inflating: content/images/1555.png
#   inflating: content/images/369.png
#   inflating: content/images/2795.png
#   inflating: content/images/1745.png
#   inflating: content/images/1581.png
#   inflating: content/images/2140.png
#   inflating: content/images/1829.png
#   inflating: content/images/506.png
#   inflating: content/images/18.jpg
#   inflating: content/images/1542.png
#   inflating: content/images/448.png
#   inflating: content/images/828.png
#   inflating: content/images/98.jpg
#   inflating: content/images/203.jpg
#   inflating: content/images/1615.png
#   inflating: content/images/3143.png
#   inflating: content/images/2090.png
#   inflating: content/images/87.jpg
#   inflating: content/images/1727.png
#   inflating: content/images/1029.png
#   inflating: content/images/3168.png
#   inflating: content/images/2424.png
#   inflating: content/images/3327.png
#   inflating: content/images/174.jpg
#   inflating: content/images/1794.png
#   inflating: content/images/2105.png
#   inflating: content/images/1125.png
#   inflating: content/images/2890.png
#   inflating: content/images/3223.png
#   inflating: content/images/1368.png
#   inflating: content/images/252.jpg
#   inflating: content/images/1241.png
#   inflating: content/images/709.png
#   inflating: content/images/999.png
#   inflating: content/images/766.png
#   inflating: content/images/1459.png
#   inflating: content/images/1632.png
#   inflating: content/images/3270.png
#   inflating: content/images/1489.png
#   inflating: content/images/2286.png
#   inflating: content/images/2502.png
#   inflating: content/images/1893.png
#   inflating: content/images/113.jpg
#   inflating: content/images/1064.png
#   inflating: content/images/3380.png
#   inflating: content/images/626.png
#   inflating: content/images/1900.png
#   inflating: content/images/903.png
#   inflating: content/images/517.png
#   inflating: content/images/2898.png
#   inflating: content/images/2312.png
#   inflating: content/images/539.png
#   inflating: content/images/3401.png
#   inflating: content/images/2651.png
#   inflating: content/images/3385.png
#   inflating: content/images/313.jpg
#   inflating: content/images/2736.png
#   inflating: content/images/235.jpg
#   inflating: content/images/2039.png
#   inflating: content/images/1997.png
#   inflating: content/images/653.png
#   inflating: content/images/1362.png
#   inflating: content/images/1834.png
#   inflating: content/images/2664.png
#   inflating: content/images/855.png
#   inflating: content/images/574.png
#   inflating: content/images/1490.png
#   inflating: content/images/204.jpg
#   inflating: content/images/3260.png
#   inflating: content/images/1861.png
#   inflating: content/images/1085.png
#   inflating: content/images/3439.png
#   inflating: content/images/1160.png
#   inflating: content/images/3383.png
#   inflating: content/images/2896.png
#   inflating: content/images/1326.png
#   inflating: content/images/2091.png
#   inflating: content/images/593.png
#   inflating: content/images/2374.png
#   inflating: content/images/379.png
#   inflating: content/images/2646.png
#   inflating: content/images/3242.png
#   inflating: content/images/2448.png
#   inflating: content/images/3331.png
#   inflating: content/images/1889.png
#   inflating: content/images/498.png
#   inflating: content/images/1704.png
#   inflating: content/images/2765.png
#   inflating: content/images/806.png
#   inflating: content/images/2817.png
#   inflating: content/images/2926.png
#   inflating: content/images/2370.png
#   inflating: content/images/2340.png
#   inflating: content/images/1943.png
#   inflating: content/images/3031.png
#   inflating: content/images/2212.png
#   inflating: content/images/50.jpg
#   inflating: content/images/1917.png
#   inflating: content/images/2082.png
#   inflating: content/images/1269.png
#   inflating: content/images/447.png
#   inflating: content/images/2734.png
#   inflating: content/images/2948.png
#   inflating: content/images/2029.png
#   inflating: content/images/3082.png
#   inflating: content/images/2133.png
#   inflating: content/images/1047.png
#   inflating: content/images/2283.png
#   inflating: content/images/1627.png
#   inflating: content/images/3226.png
#   inflating: content/images/882.png
#   inflating: content/images/629.png
#   inflating: content/images/792.png
#   inflating: content/images/3250.png
#   inflating: content/images/2488.png
#   inflating: content/images/570.png
#   inflating: content/images/1199.png
#   inflating: content/images/2594.png
#   inflating: content/images/86.jpg
#   inflating: content/images/3499.png
#   inflating: content/images/2700.png
#   inflating: content/images/121.jpg
#   inflating: content/images/908.png
#   inflating: content/images/1238.png
#   inflating: content/images/1607.png
#   inflating: content/images/1836.png
#   inflating: content/images/3516.png
#   inflating: content/images/708.png
#   inflating: content/images/2750.png
#   inflating: content/images/2603.png
#   inflating: content/images/2854.png
#   inflating: content/images/473.png
#   inflating: content/images/25.jpg
#   inflating: content/images/1189.png
#   inflating: content/images/1540.png
#   inflating: content/images/2047.png
#   inflating: content/images/1948.png
#   inflating: content/images/1659.png
#   inflating: content/images/3131.png
#   inflating: content/images/3295.png
#   inflating: content/images/1612.png
#   inflating: content/images/3157.png
#   inflating: content/images/2018.png
#   inflating: content/images/743.png
#   inflating: content/images/467.png
#   inflating: content/images/1169.png
#   inflating: content/images/283.jpg
#   inflating: content/images/1118.png
#   inflating: content/images/540.png
#   inflating: content/images/1854.png
#   inflating: content/images/923.png
#   inflating: content/images/1004.png
#   inflating: content/images/3178.png
#   inflating: content/images/2677.png
#   inflating: content/images/1003.png
#   inflating: content/images/3135.png
#   inflating: content/images/2730.png
#   inflating: content/images/3434.png
#   inflating: content/images/2638.png
#   inflating: content/images/1668.png
#   inflating: content/images/3402.png
#   inflating: content/images/1658.png
#   inflating: content/images/3060.png
#   inflating: content/images/1683.png
#   inflating: content/images/2347.png
#   inflating: content/images/1907.png
#   inflating: content/images/2715.png
#   inflating: content/images/83.jpeg
#   inflating: content/images/375.png
#   inflating: content/images/3059.png
#   inflating: content/images/3362.png
#   inflating: content/images/2636.png
#   inflating: content/images/1562.png
#   inflating: content/images/894.png
#   inflating: content/images/1961.png
#   inflating: content/images/2209.png
#   inflating: content/images/154.jpg
#   inflating: content/images/2437.png
#   inflating: content/images/2723.png
#   inflating: content/images/398.png
#   inflating: content/images/1539.png
#   inflating: content/images/1195.png
#   inflating: content/images/616.png
#   inflating: content/images/1929.png
#   inflating: content/images/1065.png
#   inflating: content/images/1355.png
#   inflating: content/images/1681.png
#   inflating: content/images/883.png
#   inflating: content/images/1048.png
#   inflating: content/images/1911.png
#   inflating: content/images/2848.png
#   inflating: content/images/2667.png
#   inflating: content/images/2542.png
#   inflating: content/images/1445.png
#   inflating: content/images/897.png
#   inflating: content/images/453.png
#   inflating: content/images/1858.png
#   inflating: content/images/2561.png
#   inflating: content/images/1293.png
#   inflating: content/images/920.png
#   inflating: content/images/2995.png
#   inflating: content/images/310.jpg
#   inflating: content/images/475.png
#   inflating: content/images/40.png
#   inflating: content/images/1038.png
#   inflating: content/images/1960.png
#   inflating: content/images/2721.png
#   inflating: content/images/3116.png
#   inflating: content/images/2452.png
#   inflating: content/images/2171.png
#   inflating: content/images/1883.png
#   inflating: content/images/3069.png
#   inflating: content/images/2413.png
#   inflating: content/images/2894.png
#   inflating: content/images/1186.png
#   inflating: content/images/496.png
#   inflating: content/images/1933.png
#   inflating: content/images/3061.png
#   inflating: content/images/2417.png
#   inflating: content/images/984.png
#   inflating: content/images/1174.png
#   inflating: content/images/23.jpg
#   inflating: content/images/2408.png
#   inflating: content/images/1752.png
#   inflating: content/images/2832.png
#   inflating: content/images/1202.png
#   inflating: content/images/258.jpg
#   inflating: content/images/2464.png
#   inflating: content/images/816.png
#   inflating: content/images/140.jpg
#   inflating: content/images/2622.png
#   inflating: content/images/3366.png
#   inflating: content/images/1556.png
#   inflating: content/images/118.jpg
#   inflating: content/images/2390.png
#   inflating: content/images/1734.png
#   inflating: content/images/2499.png
#   inflating: content/images/679.png
#   inflating: content/images/1528.png
#   inflating: content/images/3474.png
#   inflating: content/images/1786.png
#   inflating: content/images/297.jpg
#   inflating: content/images/2712.png
#   inflating: content/images/3520.png
#   inflating: content/images/1313.png
#   inflating: content/images/3140.png
#   inflating: content/images/38.jpg
#   inflating: content/images/3538.png
#   inflating: content/images/2344.png
#   inflating: content/images/3427.png
#   inflating: content/images/552.png
#   inflating: content/images/3281.png
#   inflating: content/images/2632.png
#   inflating: content/images/1134.png
#   inflating: content/images/3531.png
#   inflating: content/images/257.jpg
#   inflating: content/images/3298.png
#   inflating: content/images/1344.png
#   inflating: content/images/212.jpg
#   inflating: content/images/2853.png
#   inflating: content/images/795.png
#   inflating: content/images/800.png
#   inflating: content/images/1466.png
#   inflating: content/images/2063.png
#   inflating: content/images/2909.png
#   inflating: content/images/2891.png
#   inflating: content/images/2534.png
#   inflating: content/images/1573.png
#   inflating: content/images/958.png
#   inflating: content/images/3019.png
#   inflating: content/images/3002.png
#   inflating: content/images/1324.png
#   inflating: content/images/2885.png
#   inflating: content/images/3459.png
#   inflating: content/images/3313.png
#   inflating: content/images/592.png
#   inflating: content/images/2676.png
#   inflating: content/images/8.jpg
#   inflating: content/images/1857.png
#   inflating: content/images/991.png
#   inflating: content/images/2640.png
#   inflating: content/images/1977.png
#   inflating: content/images/3369.png
#   inflating: content/images/2004.png
#   inflating: content/images/1520.png
#   inflating: content/images/541.png
#   inflating: content/images/2141.png
#   inflating: content/images/690.png
#   inflating: content/images/1207.png
#   inflating: content/images/2154.png
#   inflating: content/images/785.png
#   inflating: content/images/1441.png
#   inflating: content/images/3332.png
#   inflating: content/images/2185.png
#   inflating: content/images/189.jpg
#   inflating: content/images/2125.png
#   inflating: content/images/988.png
#   inflating: content/images/1571.png
#   inflating: content/images/2903.png
#   inflating: content/images/2969.png
#   inflating: content/images/1534.png
#   inflating: content/images/2453.png
#   inflating: content/images/175.jpg
#   inflating: content/images/913.png
#   inflating: content/images/3215.png
#   inflating: content/images/90.jpg
#   inflating: content/images/56.jpg
#   inflating: content/images/851.png
#   inflating: content/images/1493.png
#   inflating: content/images/1359.png
#   inflating: content/images/836.png
#   inflating: content/images/1006.png
#   inflating: content/images/2131.png
#   inflating: content/images/2990.png
#   inflating: content/images/377.png
#   inflating: content/images/292.jpg
#   inflating: content/images/7.jpg
#   inflating: content/images/2624.png
#   inflating: content/images/1389.png
#   inflating: content/images/2574.png
#   inflating: content/images/338.jpg
#   inflating: content/images/2157.png
#   inflating: content/images/1176.png
#   inflating: content/images/2625.png
#   inflating: content/images/697.png
#   inflating: content/images/1730.png
#   inflating: content/images/2547.png
#   inflating: content/images/2710.png
#   inflating: content/images/1720.png
#   inflating: content/images/3450.png
#   inflating: content/images/2771.png
#   inflating: content/images/1092.png
#   inflating: content/images/893.png
#   inflating: content/images/31.jpg
#   inflating: content/images/3126.png
#   inflating: content/images/2662.png
#   inflating: content/images/161.JPG
#   inflating: content/images/1243.png
#   inflating: content/images/213.jpg
#   inflating: content/images/3120.png
#   inflating: content/images/1655.png
#   inflating: content/images/1936.png
#   inflating: content/images/2729.png
#   inflating: content/images/748.png
#   inflating: content/images/3543.png
#   inflating: content/images/678.png
#   inflating: content/images/433.png
#   inflating: content/images/3304.png
#   inflating: content/images/276.jpg
#   inflating: content/images/2528.png
#   inflating: content/images/584.png
#   inflating: content/images/763.png
#   inflating: content/images/2266.png
#   inflating: content/images/2923.png
#   inflating: content/images/341.jpg
#   inflating: content/images/2364.png
#   inflating: content/images/2759.png
#   inflating: content/images/95.jpg
#   inflating: content/images/944.png
#   inflating: content/images/1223.png
#   inflating: content/images/2103.png
#   inflating: content/images/1494.png
#   inflating: content/images/3038.png
#   inflating: content/images/1731.png
#   inflating: content/images/281.jpg
#   inflating: content/images/2287.png
#   inflating: content/images/2739.png
#   inflating: content/images/6.jpg
#   inflating: content/images/1809.png
#   inflating: content/images/1741.png
#   inflating: content/images/1251.png
#   inflating: content/images/11.jpg
#   inflating: content/images/195.jpg
#   inflating: content/images/477.png
#   inflating: content/images/1949.png
#   inflating: content/images/3171.png
#   inflating: content/images/558.png
#   inflating: content/images/1769.png
#   inflating: content/images/1217.png
#   inflating: content/images/2466.png
#   inflating: content/images/3125.png
#   inflating: content/images/2199.png
#   inflating: content/images/3338.png
#   inflating: content/images/443.png
#   inflating: content/images/288.jpg
#   inflating: content/images/853.png
#   inflating: content/images/2617.png
#   inflating: content/images/838.png
#   inflating: content/images/3247.png
#   inflating: content/images/2744.png
#   inflating: content/images/1294.png
#   inflating: content/images/3539.png
#   inflating: content/images/1871.png
#   inflating: content/images/2342.png
#   inflating: content/images/155.jpg
#   inflating: content/images/380.png
#   inflating: content/images/3463.png
#   inflating: content/images/1918.png
#   inflating: content/images/356.png
#   inflating: content/images/2038.png
#   inflating: content/images/176.jpg
#   inflating: content/images/1713.png
#   inflating: content/images/1984.png
#   inflating: content/images/3195.png
#   inflating: content/images/2981.png
#   inflating: content/images/3420.png
#   inflating: content/images/3358.png
#   inflating: content/images/3241.png
#   inflating: content/images/590.png
#   inflating: content/images/1828.png
#   inflating: content/images/2976.png
#   inflating: content/images/856.png
#   inflating: content/images/1329.png
#   inflating: content/images/3489.png
#   inflating: content/images/1040.png
#   inflating: content/images/270.jpg
#   inflating: content/images/70.jpg
#   inflating: content/images/2435.png
#   inflating: content/images/1952.png
#   inflating: content/images/827.png
#   inflating: content/images/370.png
#   inflating: content/images/2273.png
#   inflating: content/images/3246.png
#   inflating: content/images/906.png
#   inflating: content/images/1275.png
#   inflating: content/images/2548.png
#   inflating: content/images/2220.png
#   inflating: content/images/3057.png
#   inflating: content/images/1063.png
#   inflating: content/images/555.png
#   inflating: content/images/1695.png
#   inflating: content/images/1735.png
#   inflating: content/images/485.png
#   inflating: content/images/501.png
#   inflating: content/images/1785.png
#   inflating: content/images/1500.png
#   inflating: content/images/1755.png
#   inflating: content/images/2149.png
#   inflating: content/images/2821.png
#   inflating: content/images/668.png
#   inflating: content/images/2892.png
#   inflating: content/images/1724.png
#   inflating: content/images/3279.png
#   inflating: content/images/872.png
#   inflating: content/images/524.png
#   inflating: content/images/1514.png
#   inflating: content/images/314.jpg
#   inflating: content/images/3321.png
#   inflating: content/images/3080.png
#   inflating: content/images/3286.png
#   inflating: content/images/844.png
#   inflating: content/images/3432.png
#   inflating: content/images/1447.png
#   inflating: content/images/3214.png
#   inflating: content/images/43.jpg
#   inflating: content/images/182.jpg
#   inflating: content/images/1272.png
#   inflating: content/images/2797.png
#   inflating: content/images/1586.png
#   inflating: content/images/2865.png
#   inflating: content/images/2035.png
#   inflating: content/images/2316.png
#   inflating: content/images/1848.png
#   inflating: content/images/2056.png
#   inflating: content/images/2186.png
#   inflating: content/images/2755.png
#   inflating: content/images/1817.png
#   inflating: content/images/170.jpg
#   inflating: content/images/1124.png
#   inflating: content/images/2716.png
#   inflating: content/images/2429.png
#   inflating: content/images/676.png
#   inflating: content/images/2254.png
#   inflating: content/images/320.jpg
#   inflating: content/images/879.png
#   inflating: content/images/2299.png
#   inflating: content/images/1620.png
#   inflating: content/images/3297.png
#   inflating: content/images/242.jpg
#   inflating: content/images/2231.png
#   inflating: content/images/1414.png
#   inflating: content/images/3095.png
#   inflating: content/images/1166.png
#   inflating: content/images/1114.png
#   inflating: content/images/1260.png
#   inflating: content/images/1386.png
#   inflating: content/images/2069.png
#   inflating: content/images/2604.png
#   inflating: content/images/1080.png
#   inflating: content/images/1661.png
#   inflating: content/images/2514.png
#   inflating: content/images/3507.png
#   inflating: content/images/2037.png
#   inflating: content/images/637.png
#   inflating: content/images/1203.png
#   inflating: content/images/46.jpg
#   inflating: content/images/1635.png
#   inflating: content/images/3511.png
#   inflating: content/images/2107.png
#   inflating: content/images/1940.png
#   inflating: content/images/423.png
#   inflating: content/images/1172.png
#   inflating: content/images/387.png
#   inflating: content/images/3458.png
#   inflating: content/images/1899.png
#   inflating: content/images/216.jpg
#   inflating: content/images/1844.png
#   inflating: content/images/336.jpg
#   inflating: content/images/881.png
#   inflating: content/images/2415.png
#   inflating: content/images/3445.png
#   inflating: content/images/657.png
#   inflating: content/images/1339.png
#   inflating: content/images/3471.png
#   inflating: content/images/1867.png
#   inflating: content/images/51.jpg
#   inflating: content/images/3343.png
#   inflating: content/images/385.png
#   inflating: content/images/294.jpg
#   inflating: content/images/460.png
#   inflating: content/images/1298.png
#   inflating: content/images/3119.png
#   inflating: content/images/2014.png
#   inflating: content/images/3431.png
#   inflating: content/images/1231.png
#   inflating: content/images/1012.png
#   inflating: content/images/3477.png
#   inflating: content/images/2134.png
#   inflating: content/images/1860.png
#   inflating: content/images/162.jpg
#   inflating: content/images/492.png
#   inflating: content/images/2612.png
#   inflating: content/images/1046.png
#   inflating: content/images/1309.png
#   inflating: content/images/3284.png
#   inflating: content/images/2151.png
#   inflating: content/images/1393.png
#   inflating: content/images/954.png
#   inflating: content/images/1062.png
#   inflating: content/images/2355.png
#   inflating: content/images/1456.png
#   inflating: content/images/874.png
#   inflating: content/images/1855.png
#   inflating: content/images/1518.png
#   inflating: content/images/2600.png
#   inflating: content/images/99.jpg
#   inflating: content/images/1013.png
#   inflating: content/images/248.jpg
#   inflating: content/images/1626.png
#   inflating: content/images/1783.png
#   inflating: content/images/1276.png
#   inflating: content/images/3509.png
#   inflating: content/images/2980.png
#   inflating: content/images/1597.png
#   inflating: content/images/2002.png
#   inflating: content/images/823.png
#   inflating: content/images/1422.png
#   inflating: content/images/3072.png
#   inflating: content/images/2501.png
#   inflating: content/images/2889.png
#   inflating: content/images/972.png
#   inflating: content/images/880.png
#   inflating: content/images/2611.png
#   inflating: content/images/156.png
#   inflating: content/images/2241.png
#   inflating: content/images/2351.png
#   inflating: content/images/2973.png
#   inflating: content/images/2927.png
#   inflating: content/images/1215.png
#   inflating: content/images/1825.png
#   inflating: content/images/1656.png
#   inflating: content/images/2571.png
#   inflating: content/images/3005.png
#   inflating: content/images/3207.png
#   inflating: content/images/2529.png
#   inflating: content/images/1421.png
#   inflating: content/images/1230.png
#   inflating: content/images/3472.png
#   inflating: content/images/917.png
#   inflating: content/images/2517.png
#   inflating: content/images/2130.png
#   inflating: content/images/2748.png
#   inflating: content/images/3390.png
#   inflating: content/images/3335.png
#   inflating: content/images/2015.png
#   inflating: content/images/847.png
#   inflating: content/images/2460.png
#   inflating: content/images/1136.png
#   inflating: content/images/1993.png
#   inflating: content/images/1229.png
#   inflating: content/images/3386.png
#   inflating: content/images/2772.png
#   inflating: content/images/326.jpg
#   inflating: content/images/3294.png
#   inflating: content/images/29.jpg
#   inflating: content/images/744.png
#   inflating: content/images/160.jpg
#   inflating: content/images/663.png
#   inflating: content/images/1532.png
#   inflating: content/images/2689.png
#   inflating: content/images/1647.png
#   inflating: content/images/2706.png
#   inflating: content/images/3529.png
#   inflating: content/images/1448.png
#   inflating: content/images/796.png
#   inflating: content/images/868.png
#   inflating: content/images/234.jpg
#   inflating: content/images/2863.png
#   inflating: content/images/2516.png
#   inflating: content/images/2695.png
#   inflating: content/images/2883.png
#   inflating: content/images/2169.png
#   inflating: content/images/1689.png
#   inflating: content/images/1271.png
#   inflating: content/images/2191.png
#   inflating: content/images/2295.png
#   inflating: content/images/2691.png
#   inflating: content/images/933.png
#   inflating: content/images/512.png
#   inflating: content/images/442.png
#   inflating: content/images/490.png
#   inflating: content/images/2367.png
#   inflating: content/images/700.png
#   inflating: content/images/1206.png
#   inflating: content/images/451.png
#   inflating: content/images/2365.png
#   inflating: content/images/2025.png
#   inflating: content/images/509.png
#   inflating: content/images/363.png
#   inflating: content/images/1464.png
#   inflating: content/images/298.jpg
#   inflating: content/images/1295.png
#   inflating: content/images/3107.png
#   inflating: content/images/255.jpg
#   inflating: content/images/2472.png
#   inflating: content/images/3514.png
#   inflating: content/images/2481.png
#   inflating: content/images/2775.png
#   inflating: content/images/1815.png
#   inflating: content/images/2382.png
#   inflating: content/images/3039.png
#   inflating: content/images/2616.png
#   inflating: content/images/1437.png
#   inflating: content/images/457.png
#   inflating: content/images/2803.png
#   inflating: content/images/3136.png
#   inflating: content/images/179.jpg
#   inflating: content/images/148.jpg
#   inflating: content/images/1042.png
#   inflating: content/images/922.png
#   inflating: content/images/2658.png
#   inflating: content/images/2778.png
#   inflating: content/images/2297.png
#   inflating: content/images/865.png
#   inflating: content/images/78.jpg
#   inflating: content/images/2093.png
#   inflating: content/images/2722.png
#   inflating: content/images/569.png
#   inflating: content/images/586.png
#   inflating: content/images/943.png
#   inflating: content/images/1748.png
#   inflating: content/images/615.png
# ...
#   inflating: content/images/1869.png
#   inflating: content/images/1599.png
#   inflating: content/images/1884.png
#   inflating: content/images/231.jpg
#   inflating: content/images/2591.png
#   inflating: content/images/422.png
#   inflating: content/images/1274.png
#   inflating: content/images/1976.png
#   inflating: content/images/2862.png
#   inflating: content/images/1395.png
#   inflating: content/images/3091.png
#   inflating: content/images/537.png
#   inflating: content/images/1385.png
#   inflating: content/images/3485.png
#   inflating: content/images/2222.png
#   inflating: content/images/166.jpg
#   inflating: content/images/452.png
#   inflating: content/images/3353.png
#   inflating: content/images/2511.png
#   inflating: content/images/1140.png
#   inflating: content/images/2180.png
#   inflating: content/images/2269.png
#   inflating: content/images/2867.png
#   inflating: content/images/2745.png
#   inflating: content/images/3047.png
#   inflating: content/images/2527.png
#   inflating: content/images/256.jpg
#   inflating: content/images/1761.png
#   inflating: content/images/187.jpg
#   inflating: content/images/834.png
#   inflating: content/images/1958.png
#   inflating: content/images/263.JPG
#   inflating: content/images/2497.png
#   inflating: content/images/2432.png
#   inflating: content/images/1266.png
#   inflating: content/images/226.jpg
#   inflating: content/images/3264.png
#   inflating: content/images/2552.png
#   inflating: content/images/1308.png
#   inflating: content/images/2106.png
#   inflating: content/images/71.jpg
#   inflating: content/images/684.png
#   inflating: content/images/393.png
#   inflating: content/images/892.png
#   inflating: content/images/3292.png
#   inflating: content/images/2398.png
#   inflating: content/images/818.png
#   inflating: content/images/3488.png
#   inflating: content/images/3149.png
#   inflating: content/images/1469.png
#   inflating: content/images/1290.png
#   inflating: content/images/659.png
#   inflating: content/images/1427.png
#   inflating: content/images/2008.png
#   inflating: content/images/2630.png
#   inflating: content/images/1129.png
#   inflating: content/images/1703.png
#   inflating: content/images/193.JPG
#   inflating: content/images/528.png
#   inflating: content/images/862.png
#   inflating: content/images/2564.png
#   inflating: content/images/2717.png
#   inflating: content/images/1709.png
#   inflating: content/images/877.png
#   inflating: content/images/1449.png
#   inflating: content/images/2740.png
#   inflating: content/images/1744.png
#   inflating: content/images/1638.png
#   inflating: content/images/757.png
#   inflating: content/images/3189.png
#   inflating: content/images/1011.png
#   inflating: content/images/2175.png
#   inflating: content/images/2828.png
#   inflating: content/images/675.png
#   inflating: content/images/1820.png
#   inflating: content/images/3384.png
#   inflating: content/images/2147.png
#   inflating: content/images/1300.png
#   inflating: content/images/2247.png
#   inflating: content/images/2887.png
#   inflating: content/images/299.jpg
#   inflating: content/images/852.png
#   inflating: content/images/677.png
#   inflating: content/images/1135.png
#   inflating: content/images/2294.png
#   inflating: content/images/1458.png
#   inflating: content/images/3479.png
#   inflating: content/images/3341.png
#   inflating: content/images/411.png
#   inflating: content/images/2217.png
#   inflating: content/images/904.png
#   inflating: content/images/2586.png
#   inflating: content/images/981.png
#   inflating: content/images/3248.png
#   inflating: content/images/1702.png
#   inflating: content/images/1796.png
#   inflating: content/images/902.png
#   inflating: content/images/1133.png
#   inflating: content/images/1366.png
#   inflating: content/images/1901.png
#   inflating: content/images/272.jpg
#   inflating: content/images/556.png
#   inflating: content/images/2455.png
#   inflating: content/images/1190.png
#   inflating: content/images/3199.png
#   inflating: content/images/1965.png
#   inflating: content/images/415.png
#   inflating: content/images/3505.png
#   inflating: content/images/2100.png
#   inflating: content/images/47.jpg
#   inflating: content/images/2705.png
#   inflating: content/images/1839.png
#   inflating: content/images/2265.png
#   inflating: content/images/2950.png
#   inflating: content/images/2479.png
#   inflating: content/images/1614.png
#   inflating: content/images/1576.png
#   inflating: content/images/3176.png
#   inflating: content/images/2957.png
#   inflating: content/images/2322.png
#   inflating: content/images/2520.png
#   inflating: content/images/2081.png
#   inflating: content/images/3410.png
#   inflating: content/images/1304.png
#   inflating: content/images/1505.png
#   inflating: content/images/2076.png
#   inflating: content/images/3162.png
#   inflating: content/images/251.jpg
#   inflating: content/images/1409.png
#   inflating: content/images/470.png
#   inflating: content/images/968.png
#   inflating: content/images/1962.png
#   inflating: content/images/1018.png
#   inflating: content/images/1167.png
#   inflating: content/images/1535.png
#   inflating: content/images/3139.png
#   inflating: content/images/373.png
#   inflating: content/images/2551.png
#   inflating: content/images/417.png
#   inflating: content/images/1093.png
#   inflating: content/images/3306.png
#   inflating: content/images/2381.png
#   inflating: content/images/2777.png
#   inflating: content/images/3154.png
#   inflating: content/images/1950.png
#   inflating: content/images/1673.png
#   inflating: content/images/1286.png
#   inflating: content/images/2587.png
#   inflating: content/images/624.png
#   inflating: content/images/3050.png
#   inflating: content/images/169.jpg
#   inflating: content/images/2394.png
#   inflating: content/images/2815.png
#   inflating: content/images/538.png
#   inflating: content/images/2878.png
#   inflating: content/images/360.png
#   inflating: content/images/2438.png
#   inflating: content/images/2326.png
#   inflating: content/images/1935.png
#   inflating: content/images/3224.png
#   inflating: content/images/133.jpg
#   inflating: content/images/788.png
#   inflating: content/images/1099.png
#   inflating: content/images/478.png
#   inflating: content/images/330.JPG
#   inflating: content/images/328.jpg
#   inflating: content/images/905.png
#   inflating: content/images/1654.png
#   inflating: content/images/488.png
#   inflating: content/images/1795.png
#   inflating: content/images/3467.png
#   inflating: content/images/1872.png
#   inflating: content/images/2311.png
#   inflating: content/images/157.jpg
#   inflating: content/images/2851.png
#   inflating: content/images/3183.png
#   inflating: content/images/926.png
#   inflating: content/images/2285.png
#   inflating: content/images/1455.png
#   inflating: content/images/2621.png
#   inflating: content/images/3470.png
#   inflating: content/images/3345.png
#   inflating: content/images/1184.png
#   inflating: content/images/3147.png
#   inflating: content/images/1205.png
#   inflating: content/images/2881.png
#   inflating: content/images/3457.png
#   inflating: content/images/3289.png
#   inflating: content/images/1058.png
#   inflating: content/images/1894.png
#   inflating: content/images/52.jpg
#   inflating: content/images/1185.png
#   inflating: content/images/940.png
#   inflating: content/images/1392.png
#   inflating: content/images/3065.png
#   inflating: content/images/1209.png
#   inflating: content/images/2198.png
#   inflating: content/images/864.png
#   inflating: content/images/2780.png
#   inflating: content/images/1280.png
#   inflating: content/images/3487.png
#   inflating: content/images/3406.png
#   inflating: content/images/1127.png
#   inflating: content/images/3020.png
#   inflating: content/images/3464.png
#   inflating: content/images/873.png
#   inflating: content/images/2504.png
#   inflating: content/images/1553.png
#   inflating: content/images/376.png
#   inflating: content/images/3351.png
#   inflating: content/images/114.jpg
#   inflating: content/images/355.png
#   inflating: content/images/3403.png
#   inflating: content/images/1633.png
#   inflating: content/images/3093.png
#   inflating: content/images/3232.png
#   inflating: content/images/418.png
#   inflating: content/images/953.png
#   inflating: content/images/2219.png
#   inflating: content/images/688.png
#   inflating: content/images/1777.png
#   inflating: content/images/2296.png
#   inflating: content/images/1327.png
#   inflating: content/images/939.png
#   inflating: content/images/2794.png
#   inflating: content/images/1726.png
#   inflating: content/images/3496.png
#   inflating: content/images/527.png
#   inflating: content/images/681.png
#   inflating: content/images/2087.png
#   inflating: content/images/1887.png
#   inflating: content/images/2535.png
#   inflating: content/images/896.png
#   inflating: content/images/3094.png
#   inflating: content/images/1495.png
#   inflating: content/images/227.jpg
#   inflating: content/images/3164.png
#   inflating: content/images/833.png
#   inflating: content/images/1973.png
#   inflating: content/images/2005.png
#   inflating: content/images/2258.png
#   inflating: content/images/977.png
#   inflating: content/images/2115.png
#   inflating: content/images/2733.png
#   inflating: content/images/1882.png
#   inflating: content/images/1208.png
#   inflating: content/images/163.jpg
#   inflating: content/images/3029.png
#   inflating: content/images/1653.png
#   inflating: content/images/3389.png
#   inflating: content/images/2041.png
#   inflating: content/images/3244.png
#   inflating: content/images/1959.png
#   inflating: content/images/2627.png
#   inflating: content/images/729.png
#   inflating: content/images/2403.png
#   inflating: content/images/699.png
#   inflating: content/images/949.png
#   inflating: content/images/59.jpg
#   inflating: content/images/3318.png
#   inflating: content/images/332.jpg
#   inflating: content/images/2279.png
#   inflating: content/images/932.png
#   inflating: content/images/2030.png
#   inflating: content/images/550.png
#   inflating: content/images/3170.png
#   inflating: content/images/1643.png
#   inflating: content/images/829.png
#   inflating: content/images/254.jpg
#   inflating: content/images/134.jpg
#   inflating: content/images/2880.png
#   inflating: content/images/49.jpg
#   inflating: content/images/280.jpg
#   inflating: content/images/346.jpg
#   inflating: content/images/2158.png
#   inflating: content/images/199.jpg
#   inflating: content/images/899.png
#   inflating: content/images/1198.png
#   inflating: content/images/1252.png
#   inflating: content/images/446.png
#   inflating: content/images/859.png
#   inflating: content/images/2350.png
#   inflating: content/images/1472.png
#   inflating: content/images/3419.png
#   inflating: content/images/2378.png
#   inflating: content/images/269.jpg
#   inflating: content/images/1779.png
#   inflating: content/images/2619.png
#   inflating: content/images/878.png
#   inflating: content/images/3024.png
#   inflating: content/images/1800.png
#   inflating: content/images/993.png
#   inflating: content/images/1663.png
#   inflating: content/images/2260.png
#   inflating: content/images/3413.png
#   inflating: content/images/2615.png
#   inflating: content/images/854.png
#   inflating: content/images/3416.png
#   inflating: content/images/3277.png
#   inflating: content/images/2430.png
#   inflating: content/images/1606.png
#   inflating: content/images/707.png
#   inflating: content/images/2111.png
#   inflating: content/images/794.png
#   inflating: content/images/2092.png
#   inflating: content/images/1122.png
#   inflating: content/images/3004.png
#   inflating: content/images/702.png
#   inflating: content/images/319.jpg
#   inflating: content/images/1182.png
#   inflating: content/images/1625.png
#   inflating: content/images/3451.png
#   inflating: content/images/1116.png
#   inflating: content/images/1412.png
#   inflating: content/images/1028.png
#   inflating: content/images/2977.png
#   inflating: content/images/2376.png
#   inflating: content/images/608.png
#   inflating: content/images/549.png
#   inflating: content/images/1501.png
#   inflating: content/images/75.jpg
#   inflating: content/images/1301.png
#   inflating: content/images/1094.png
#   inflating: content/images/2164.png
#   inflating: content/images/2670.png
#   inflating: content/images/3102.png
#   inflating: content/images/1789.png
#   inflating: content/images/2425.png
#   inflating: content/images/2808.png
#   inflating: content/images/1765.png
#   inflating: content/images/232.jpg
#   inflating: content/images/1996.png
#   inflating: content/images/695.png
#   inflating: content/images/1303.png
#   inflating: content/images/3280.png
#   inflating: content/images/2941.png
#   inflating: content/images/1594.png
#   inflating: content/images/1582.png
#   inflating: content/images/481.png
#   inflating: content/images/322.jpg
#   inflating: content/images/2907.png
#   inflating: content/images/2036.png
#   inflating: content/images/2581.png
#   inflating: content/images/316.jpg
#   inflating: content/images/2899.png
#   inflating: content/images/1224.png
#   inflating: content/images/3098.png
#   inflating: content/images/139.jpg
#   inflating: content/images/1370.png
#   inflating: content/images/1675.png
#   inflating: content/images/2554.png
#   inflating: content/images/2224.png
#   inflating: content/images/1305.png
#   inflating: content/images/1369.png
#   inflating: content/images/286.jpg
#   inflating: content/images/825.png
#   inflating: content/images/529.png
#   inflating: content/images/1790.png
#   inflating: content/images/2576.png
#   inflating: content/images/2800.png
#   inflating: content/images/1360.png
#   inflating: content/images/2349.png
#   inflating: content/images/1256.png
#   inflating: content/images/680.png
#   inflating: content/images/965.png
#   inflating: content/images/2284.png
#   inflating: content/images/1482.png
#   inflating: content/images/2928.png
#   inflating: content/images/105.jpg
#   inflating: content/images/1913.png
#   inflating: content/images/790.png
#   inflating: content/images/230.jpg
#   inflating: content/images/1814.png
#   inflating: content/images/2251.png
#   inflating: content/images/2707.png
#   inflating: content/images/548.png
#   inflating: content/images/1225.png
#   inflating: content/images/1220.png
#   inflating: content/images/2048.png
#   inflating: content/images/1306.png
#   inflating: content/images/2214.png
#   inflating: content/images/419.png
#   inflating: content/images/3288.png
#   inflating: content/images/887.png
#   inflating: content/images/2629.png
#   inflating: content/images/1691.png
#   inflating: content/images/491.png
#   inflating: content/images/1477.png
#   inflating: content/images/3123.png
#   inflating: content/images/382.png
#   inflating: content/images/307.jpg
#   inflating: content/images/1711.png
#   inflating: content/images/3430.png
#   inflating: content/images/3088.png
#   inflating: content/images/289.jpg
#   inflating: content/images/563.png
#   inflating: content/images/566.png
#   inflating: content/images/1079.png
#   inflating: content/images/438.png
#   inflating: content/images/2953.png
#   inflating: content/images/295.jpg
#   inflating: content/images/345.jpg
#   inflating: content/images/3300.png
#   inflating: content/images/813.png
#   inflating: content/images/2168.png
#   inflating: content/images/130.jpg
#   inflating: content/images/2465.png
#   inflating: content/images/2982.png
#   inflating: content/images/1847.png
#   inflating: content/images/14.jpg
#   inflating: content/images/2979.png
#   inflating: content/images/3053.png
#   inflating: content/images/3545.png

# %%
import glob
from natsort import natsorted

bbs = glob.glob("/content/content/labels/*")
fnames = glob.glob("/content/content/images/*")

fnames = natsorted(fnames)
filenames = []
bbox = []
for idx, f in enumerate(fnames):
  filenames.append(f.split('/')[-1])
  bbox.append(f.split('/')[-1].split('.')[0] + '.txt')

df = pd.DataFrame()
df['images'] = filenames
df['labels'] = bbox

# %%
df_train = df[:int(0.7*len(df))]
df_val = df[int(0.7*len(df)):int(0.8*len(df))]
df_test = df[int(0.8*len(df)):]
df_train.to_csv("train.csv", header=False, index=False)
df_val.to_csv("val.csv", header=False, index=False)
df_test.to_csv("test.csv", header=False, index=False)

# %% [markdown]
# ###Utils

# %%
import torch
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patches as patches
from collections import Counter

def intersection_over_union(boxes_preds, boxes_labels, box_format="midpoint"):
    """
    Calculates intersection over union

    Parameters:
        boxes_preds (tensor): Predictions of Bounding Boxes (BATCH_SIZE, 4)
        boxes_labels (tensor): Correct labels of Bounding Boxes (BATCH_SIZE, 4)
        box_format (str): midpoint/corners, if boxes (x,y,w,h) or (x1,y1,x2,y2)

    Returns:
        tensor: Intersection over union for all examples
    """

    if box_format == "midpoint":
        box1_x1 = boxes_preds[..., 0:1] - boxes_preds[..., 2:3] / 2
        box1_y1 = boxes_preds[..., 1:2] - boxes_preds[..., 3:4] / 2
        box1_x2 = boxes_preds[..., 0:1] + boxes_preds[..., 2:3] / 2
        box1_y2 = boxes_preds[..., 1:2] + boxes_preds[..., 3:4] / 2
        box2_x1 = boxes_labels[..., 0:1] - boxes_labels[..., 2:3] / 2
        box2_y1 = boxes_labels[..., 1:2] - boxes_labels[..., 3:4] / 2
        box2_x2 = boxes_labels[..., 0:1] + boxes_labels[..., 2:3] / 2
        box2_y2 = boxes_labels[..., 1:2] + boxes_labels[..., 3:4] / 2

    if box_format == "corners":
        box1_x1 = boxes_preds[..., 0:1]
        box1_y1 = boxes_preds[..., 1:2]
        box1_x2 = boxes_preds[..., 2:3]
        box1_y2 = boxes_preds[..., 3:4]  # (N, 1)
        box2_x1 = boxes_labels[..., 0:1]
        box2_y1 = boxes_labels[..., 1:2]
        box2_x2 = boxes_labels[..., 2:3]
        box2_y2 = boxes_labels[..., 3:4]

    x1 = torch.max(box1_x1, box2_x1)
    y1 = torch.max(box1_y1, box2_y1)
    x2 = torch.min(box1_x2, box2_x2)
    y2 = torch.min(box1_y2, box2_y2)

    # .clamp(0) is for the case when they do not intersect
    intersection = (x2 - x1).clamp(0) * (y2 - y1).clamp(0)

    box1_area = abs((box1_x2 - box1_x1) * (box1_y2 - box1_y1))
    box2_area = abs((box2_x2 - box2_x1) * (box2_y2 - box2_y1))

    return intersection / (box1_area + box2_area - intersection + 1e-6)


def non_max_suppression(bboxes, iou_threshold, threshold, box_format="corners"):
    """
    Does Non Max Suppression given bboxes

    Parameters:
        bboxes (list): list of lists containing all bboxes with each bboxes
        specified as [class_pred, prob_score, x1, y1, x2, y2]
        iou_threshold (float): threshold where predicted bboxes is correct
        threshold (float): threshold to remove predicted bboxes (independent of IoU) 
        box_format (str): "midpoint" or "corners" used to specify bboxes

    Returns:
        list: bboxes after performing NMS given a specific IoU threshold
    """

    assert type(bboxes) == list

    bboxes = [box for box in bboxes if box[1] > threshold]
    bboxes = sorted(bboxes, key=lambda x: x[1], reverse=True)
    bboxes_after_nms = []

    while bboxes:
        chosen_box = bboxes.pop(0)

        bboxes = [
            box
            for box in bboxes
            if box[0] != chosen_box[0]
            or intersection_over_union(
                torch.tensor(chosen_box[2:]),
                torch.tensor(box[2:]),
                box_format=box_format,
            )
            < iou_threshold
        ]

        bboxes_after_nms.append(chosen_box)

    return bboxes_after_nms


def mean_average_precision(
    pred_boxes, true_boxes, iou_threshold=0.5, box_format="midpoint", num_classes=3
):
    """
    Calculates mean average precision 

    Parameters:
        pred_boxes (list): list of lists containing all bboxes with each bboxes
        specified as [train_idx, class_prediction, prob_score, x1, y1, x2, y2]
        true_boxes (list): Similar as pred_boxes except all the correct ones 
        iou_threshold (float): threshold where predicted bboxes is correct
        box_format (str): "midpoint" or "corners" used to specify bboxes
        num_classes (int): number of classes

    Returns:
        float: mAP value across all classes given a specific IoU threshold 
    """

    # list storing all AP for respective classes
    average_precisions = []

    # used for numerical stability later on
    epsilon = 1e-6

    for c in range(num_classes):
        detections = []
        ground_truths = []

        # Go through all predictions and targets,
        # and only add the ones that belong to the
        # current class c
        for detection in pred_boxes:
            if detection[1] == c:
                detections.append(detection)

        for true_box in true_boxes:
            if true_box[1] == c:
                ground_truths.append(true_box)

        # find the amount of bboxes for each training example
        # Counter here finds how many ground truth bboxes we get
        # for each training example, so let's say img 0 has 3,
        # img 1 has 5 then we will obtain a dictionary with:
        # amount_bboxes = {0:3, 1:5}
        amount_bboxes = Counter([gt[0] for gt in ground_truths])

        # We then go through each key, val in this dictionary
        # and convert to the following (w.r.t same example):
        # ammount_bboxes = {0:torch.tensor[0,0,0], 1:torch.tensor[0,0,0,0,0]}
        for key, val in amount_bboxes.items():
            amount_bboxes[key] = torch.zeros(val)

        # sort by box probabilities which is index 2
        detections.sort(key=lambda x: x[2], reverse=True)
        TP = torch.zeros((len(detections)))
        FP = torch.zeros((len(detections)))
        total_true_bboxes = len(ground_truths)
        
        # If none exists for this class then we can safely skip
        if total_true_bboxes == 0:
            continue

        for detection_idx, detection in enumerate(detections):
            # Only take out the ground_truths that have the same
            # training idx as detection
            ground_truth_img = [
                bbox for bbox in ground_truths if bbox[0] == detection[0]
            ]

            num_gts = len(ground_truth_img)
            best_iou = 0

            for idx, gt in enumerate(ground_truth_img):
                iou = intersection_over_union(
                    torch.tensor(detection[3:]),
                    torch.tensor(gt[3:]),
                    box_format=box_format,
                )

                if iou > best_iou:
                    best_iou = iou
                    best_gt_idx = idx

            if best_iou > iou_threshold:
                # only detect ground truth detection once
                if amount_bboxes[detection[0]][best_gt_idx] == 0:
                    # true positive and add this bounding box to seen
                    TP[detection_idx] = 1
                    amount_bboxes[detection[0]][best_gt_idx] = 1
                else:
                    FP[detection_idx] = 1

            # if IOU is lower then the detection is a false positive
            else:
                FP[detection_idx] = 1

        TP_cumsum = torch.cumsum(TP, dim=0)
        FP_cumsum = torch.cumsum(FP, dim=0)
        recalls = TP_cumsum / (total_true_bboxes + epsilon)
        precisions = torch.divide(TP_cumsum, (TP_cumsum + FP_cumsum + epsilon))
        precisions = torch.cat((torch.tensor([1]), precisions))
        recalls = torch.cat((torch.tensor([0]), recalls))
        # torch.trapz for numerical integration
        average_precisions.append(torch.trapz(precisions, recalls))

    return sum(average_precisions) / len(average_precisions)


def plot_image(image, boxes):
    """Plots predicted bounding boxes on the image"""
    im = np.array(image)
    height, width, _ = im.shape

    # Create figure and axes
    fig, ax = plt.subplots(1)
    # Display the image
    ax.imshow(im)

    # box[0] is x midpoint, box[2] is width
    # box[1] is y midpoint, box[3] is height

    id_to_label = {0: "burger", 1: "drinks", 2: "fries"}
    id_to_color = {0: 'red', 1: 'yellow', 2:'green'}

    # Create a Rectangle potch
    for box in boxes:
        label = box[0]
        conf = box[1]
        box = box[2:]
        assert len(box) == 4, "Got more values than in x, y, w, h, in a box!"
        upper_left_x = box[0] - box[2] / 2
        upper_left_y = box[1] - box[3] / 2
        rect = patches.Rectangle(
            (upper_left_x * width, upper_left_y * height),
            box[2] * width,
            box[3] * height,
            linewidth=1,
            edgecolor="r",
            facecolor="none",
        )
        # Add the patch to the Axes
        ax.add_patch(rect)
        ax.annotate(id_to_label[int(label)], (upper_left_x * width, upper_left_y * height), color=id_to_color[int(label)], weight='bold', fontsize=10, ha='center', va='center')

    plt.show()

def get_bboxes(
    loader,
    model,
    iou_threshold,
    threshold,
    pred_format="cells",
    box_format="midpoint",
    device="cuda",
):
    all_pred_boxes = []
    all_true_boxes = []

    # make sure model is in eval before get bboxes
    model.eval()
    train_idx = 0

    for batch_idx, (x, labels) in enumerate(loader):
        x = x.to(device)
        labels = labels.to(device)
        # print(x.shape)
        with torch.no_grad():
            predictions = model(x)

        batch_size = x.shape[0]
        true_bboxes = cellboxes_to_boxes(labels)
        bboxes = cellboxes_to_boxes(predictions)

        for idx in range(batch_size):
            nms_boxes = non_max_suppression(
                bboxes[idx],
                iou_threshold=iou_threshold,
                threshold=threshold,
                box_format=box_format,
            )


            #if batch_idx == 0 and idx == 0:
            #    plot_image(x[idx].permute(1,2,0).to("cpu"), nms_boxes)
            #    print(nms_boxes)

            for nms_box in nms_boxes:
                all_pred_boxes.append([train_idx] + nms_box)

            for box in true_bboxes[idx]:
                # many will get converted to 0 pred
                if box[1] > threshold:
                    all_true_boxes.append([train_idx] + box)

            train_idx += 1

    model.train()
    return all_pred_boxes, all_true_boxes



def convert_cellboxes(predictions, S=7):
    """
    Converts bounding boxes output from Yolo with
    an image split size of S into entire image ratios
    rather than relative to cell ratios.
    """

    predictions = predictions.to("cpu")
    batch_size = predictions.shape[0]
    predictions = predictions.reshape(batch_size, 7, 7, 13)
    bboxes1 = predictions[..., 4:8]
    bboxes2 = predictions[..., 9:13]
    scores = torch.cat(
        (predictions[..., 3].unsqueeze(0), predictions[..., 8].unsqueeze(0)), dim=0
    )
    best_box = scores.argmax(0).unsqueeze(-1)
    best_boxes = bboxes1 * (1 - best_box) + best_box * bboxes2
    cell_indices = torch.arange(7).repeat(batch_size, 7, 1).unsqueeze(-1)
    x = 1 / S * (best_boxes[..., :1] + cell_indices)
    y = 1 / S * (best_boxes[..., 1:2] + cell_indices.permute(0, 2, 1, 3))
    w_y = 1 / S * best_boxes[..., 2:4]
    converted_bboxes = torch.cat((x, y, w_y), dim=-1)
    predicted_class = predictions[..., :3].argmax(-1).unsqueeze(-1)
    best_confidence = torch.max(predictions[..., 3], predictions[..., 8]).unsqueeze(
        -1
    )
    converted_preds = torch.cat(
        (predicted_class, best_confidence, converted_bboxes), dim=-1
    )

    return converted_preds


def cellboxes_to_boxes(out, S=7):
    converted_pred = convert_cellboxes(out).reshape(out.shape[0], S * S, -1)
    converted_pred[..., 0] = converted_pred[..., 0].long()
    all_bboxes = []

    for ex_idx in range(out.shape[0]):
        bboxes = []

        for bbox_idx in range(S * S):
            bboxes.append([x.item() for x in converted_pred[ex_idx, bbox_idx, :]])
        all_bboxes.append(bboxes)

    return all_bboxes

def save_checkpoint(state, filename="my_checkpoint.pth.tar"):
    print("=> Saving checkpoint")
    torch.save(state, filename)


def load_checkpoint(checkpoint, model, optimizer):
    print("=> Loading checkpoint")
    model.load_state_dict(checkpoint["state_dict"])
    optimizer.load_state_dict(checkpoint["optimizer"])

# %% [markdown]
# ###Yolo Architecture

# %%
architecture_config = [
    (7, 64, 2, 3),
    "M",
    (3, 192, 1, 1),
    "M",
    (1, 128, 1, 0),
    (3, 256, 1, 1),
    (1, 256, 1, 0),
    (3, 512, 1, 1),
    "M",
    [(1, 256, 1, 0), (3, 512, 1, 1), 4],
    (1, 512, 1, 0),
    (3, 1024, 1, 1),
    "M",
    [(1, 512, 1, 0), (3, 1024, 1, 1), 2],
    (3, 1024, 1, 1),
    (3, 1024, 2, 1),
    (3, 1024, 1, 1),
    (3, 1024, 1, 1),
]


class CNNBlock(nn.Module):
    def __init__(self, in_channels, out_channels, **kwargs):
        super(CNNBlock, self).__init__()
        self.conv = nn.Conv2d(in_channels, out_channels, bias=False, **kwargs)
        self.batchnorm = nn.BatchNorm2d(out_channels)
        self.leakyrelu = nn.LeakyReLU(0.1)

    def forward(self, x):
        return self.leakyrelu(self.batchnorm(self.conv(x)))


class Yolov1(nn.Module):
    def __init__(self, in_channels=3, **kwargs):
        super(Yolov1, self).__init__()
        self.architecture = architecture_config
        self.in_channels = in_channels
        self.darknet = self._create_conv_layers(self.architecture)
        self.fcs = self._create_fcs(**kwargs)

    def forward(self, x):
        x = self.darknet(x)
        return self.fcs(torch.flatten(x, start_dim=1))

    def _create_conv_layers(self, architecture):
        layers = []
        in_channels = self.in_channels

        for x in architecture:
            if type(x) == tuple:
                layers += [
                    CNNBlock(
                        in_channels, x[1], kernel_size=x[0], stride=x[2], padding=x[3],
                    )
                ]
                in_channels = x[1]

            elif type(x) == str:
                layers += [nn.MaxPool2d(kernel_size=(2, 2), stride=(2, 2))]

            elif type(x) == list:
                conv1 = x[0]
                conv2 = x[1]
                num_repeats = x[2]

                for _ in range(num_repeats):
                    layers += [
                        CNNBlock(
                            in_channels,
                            conv1[1],
                            kernel_size=conv1[0],
                            stride=conv1[2],
                            padding=conv1[3],
                        )
                    ]
                    layers += [
                        CNNBlock(
                            conv1[1],
                            conv2[1],
                            kernel_size=conv2[0],
                            stride=conv2[2],
                            padding=conv2[3],
                        )
                    ]
                    in_channels = conv2[1]

        return nn.Sequential(*layers)

    def _create_fcs(self, split_size, num_boxes, num_classes):
        S, B, C = split_size, num_boxes, num_classes

        return nn.Sequential(
            nn.Flatten(),
            nn.Linear(1024*S*S, 4096),
            nn.LeakyReLU(0.1),
            nn.Linear(4096, S*S*(B*5+C)),
        )

# %% [markdown]
# ###Yolo Loss

# %%
class YoloLoss(nn.Module):

    def __init__(self, S=7, B=2, C=3):
        super(YoloLoss, self).__init__()
        self.mse = nn.MSELoss(reduction="sum")

        self.S = S
        self.B = B
        self.C = C

        self.lambda_noobj = 0.5
        self.lambda_coord = 5

    def forward(self, predictions, target):
        predictions = predictions.reshape(-1, self.S, self.S, self.C + self.B * 5)

        iou_b1 = intersection_over_union(predictions[..., 4:8], target[..., 4:8])
        iou_b2 = intersection_over_union(predictions[..., 9:13], target[..., 4:8])
        ious = torch.cat([iou_b1.unsqueeze(0), iou_b2.unsqueeze(0)], dim=0)

        iou_maxes, bestbox = torch.max(ious, dim=0)
        exists_box = target[..., 3].unsqueeze(3)  


        box_predictions = exists_box * (
            (
                bestbox * predictions[..., 9:13]
                + (1 - bestbox) * predictions[..., 4:8]
            )
        )

        box_targets = exists_box * target[..., 4:8]

        box_predictions[..., 2:4] = torch.sign(box_predictions[..., 2:4]) * torch.sqrt(
            torch.abs(box_predictions[..., 2:4] + 1e-6)
        )
        box_targets[..., 2:4] = torch.sqrt(box_targets[..., 2:4])

        box_loss = self.mse(
            torch.flatten(box_predictions, end_dim=-2),
            torch.flatten(box_targets, end_dim=-2),
        )

        pred_box = (
            bestbox * predictions[..., 8:9] + (1 - bestbox) * predictions[..., 3:4]
        )

        object_loss = self.mse(
            torch.flatten(exists_box * pred_box),
            torch.flatten(exists_box * target[..., 3:4]),
        )

        no_object_loss = self.mse(
            torch.flatten((1 - exists_box) * predictions[..., 3:4], start_dim=1),
            torch.flatten((1 - exists_box) * target[..., 3:4], start_dim=1),
        )

        no_object_loss += self.mse(
            torch.flatten((1 - exists_box) * predictions[..., 8:9], start_dim=1),
            torch.flatten((1 - exists_box) * target[..., 3:4], start_dim=1)
        )

        class_loss = self.mse(
            torch.flatten(exists_box * predictions[..., :3], end_dim=-2,),
            torch.flatten(exists_box * target[..., :3], end_dim=-2,),
        )

        loss = (
            self.lambda_coord * box_loss
            + object_loss
            + self.lambda_noobj * no_object_loss
            + class_loss
        )

        return loss

# %% [markdown]
# ###Yolo Dataset

# %%
class VOCDataset(torch.utils.data.Dataset):
    def __init__(
        self, csv_file, img_dir, label_dir, S=7, B=2, C=3, transform=None,
    ):
        self.annotations = pd.read_csv(csv_file)
        self.img_dir = img_dir
        self.label_dir = label_dir
        self.transform = transform
        self.S = S
        self.B = B
        self.C = C

    def __len__(self):
        return len(self.annotations)

    def __getitem__(self, index):
        label_path = os.path.join(self.label_dir, self.annotations.iloc[index, 1])
        boxes = []
        with open(label_path) as f:
            for label in f.readlines():
                class_label, x, y, width, height = [
                    float(x) if float(x) != int(float(x)) else int(x)
                    for x in label.replace("\n", "").split()
                ]

                boxes.append([class_label, x, y, width, height])

        img_path = os.path.join(self.img_dir, self.annotations.iloc[index, 0])
        image = Image.open(img_path)
        boxes = torch.tensor(boxes)

        if self.transform:
            # image = self.transform(image)
            image, boxes = self.transform(image, boxes)

        if image.shape[0] == 4:
          #slice off the alpha channel
          image = image[:3, :, :]
        # Convert To Cells
        # label_matrix = torch.zeros((self.S, self.S, self.C + 5 * self.B))
        label_matrix = torch.zeros((self.S, self.S, 13))
        for box in boxes:
            class_label, x, y, width, height = box.tolist()
            class_label = int(class_label)

            # i,j represents the cell row and cell column
            i, j = int(self.S * y), int(self.S * x)
            x_cell, y_cell = self.S * x - j, self.S * y - i

            """
            Calculating the width and height of cell of bounding box,
            relative to the cell is done by the following, with
            width as the example:
            
            width_pixels = (width*self.image_width)
            cell_pixels = (self.image_width)
            
            Then to find the width relative to the cell is simply:
            width_pixels/cell_pixels, simplification leads to the
            formulas below.
            """
            width_cell, height_cell = (
                width * self.S,
                height * self.S,
            )

            # If no object already found for specific cell i,j
            # Note: This means we restrict to ONE object
            # per cell!
            if label_matrix[i, j, 3] == 0:
                # Set that there exists an object
                label_matrix[i, j, 3] = 1

                # Box coordinates
                box_coordinates = torch.tensor(
                    [x_cell, y_cell, width_cell, height_cell]
                )

                label_matrix[i, j, 4:8] = box_coordinates

                # Set one hot encoding for class_label
                label_matrix[i, j, class_label] = 1
        return image, label_matrix

# %% [markdown]
# ###Training

# %%
"""
Main file for training Yolo model on Pascal VOC dataset

"""

import torch
import torchvision.transforms as transforms
import torch.optim as optim
import torchvision.transforms.functional as FT
from tqdm import tqdm
from torch.utils.data import DataLoader

seed = 123
torch.manual_seed(seed)

# Hyperparameters etc. 
LEARNING_RATE = 2e-5
DEVICE = "cuda" if torch.cuda.is_available else "cpu"
BATCH_SIZE = 16
WEIGHT_DECAY = 0
EPOCHS = 9
NUM_WORKERS = 2
PIN_MEMORY = True
LOAD_MODEL = True
# LOAD_MODEL_FILE = "model.pth.tar"
LOAD_MODEL_FILE = "/content/drive/MyDrive/CS5242/41_model.pth.tar"
IMG_DIR = "/content/content/images"
LABEL_DIR = "/content/content/labels"


class Compose(object):
    def __init__(self, transforms):
        self.transforms = transforms

    def __call__(self, img, bboxes):
        for t in self.transforms:
            img, bboxes = t(img), bboxes

        return img, bboxes


transform = Compose([transforms.Resize((448, 448)), transforms.ToTensor(),])

log_train = []

def train_fn(train_loader, model, optimizer, loss_fn):
    loop = tqdm(train_loader, leave=True)
    mean_loss = []

    for batch_idx, (x, y) in enumerate(loop):
        x, y = x.to(DEVICE), y.to(DEVICE)
        out = model(x)
        loss = loss_fn(out, y)
        mean_loss.append(loss.item())
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        # update progress bar
        loop.set_postfix(loss=loss.item())
    mean_train = sum(mean_loss)/len(mean_loss)
    log_train.append(mean_train)
    print(f"Mean loss was {mean_train}")


model = Yolov1(split_size=7, num_boxes=2, num_classes=3).to(DEVICE)
optimizer = optim.Adam(
    model.parameters(), lr=LEARNING_RATE, weight_decay=WEIGHT_DECAY
)
loss_fn = YoloLoss()

if LOAD_MODEL:
    load_checkpoint(torch.load(LOAD_MODEL_FILE), model, optimizer)

train_dataset = VOCDataset(
    "/content/train.csv",
    transform=transform,
    img_dir=IMG_DIR,
    label_dir=LABEL_DIR,
)

val_dataset = VOCDataset(
    "/content/val.csv",
    transform=transform,
    img_dir=IMG_DIR,
    label_dir=LABEL_DIR,
)

test_dataset = VOCDataset(
    "/content/test.csv",
    transform=transform,
    img_dir=IMG_DIR,
    label_dir=LABEL_DIR,
)

train_loader = DataLoader(
    dataset=train_dataset,
    batch_size=BATCH_SIZE,
    num_workers=NUM_WORKERS,
    pin_memory=PIN_MEMORY,
    shuffle=True,
    drop_last=True,
)

val_loader = DataLoader(
    dataset=val_dataset,
    batch_size=BATCH_SIZE,
    num_workers=NUM_WORKERS,
    pin_memory=PIN_MEMORY,
    shuffle=True,
    drop_last=True,
)

test_loader = DataLoader(
    dataset=test_dataset,
    batch_size=BATCH_SIZE,
    num_workers=NUM_WORKERS,
    pin_memory=PIN_MEMORY,
    shuffle=True,
    drop_last=True,
)

for epoch in range(EPOCHS):

    pred_boxes, target_boxes = get_bboxes(
        val_loader, model, iou_threshold=0.5, threshold=0.4
    )

    mean_avg_prec = mean_average_precision(
        pred_boxes, target_boxes, iou_threshold=0.5, box_format="midpoint"
    )
    print(f"Val mAP: {mean_avg_prec}")

    if mean_avg_prec > 0.8:
       checkpoint = {
           "state_dict": model.state_dict(),
           "optimizer": optimizer.state_dict(),
       }
       save_checkpoint(checkpoint, filename=f"{epoch}_{LOAD_MODEL_FILE}")
       print("SAVED")

    train_fn(train_loader, model, optimizer, loss_fn)
# Out:
# => Loading checkpoint
# Val mAP: 0.8487206101417542
# 100%|██████████| 155/155 [03:04<00:00,  1.19s/it, loss=5.67]
# Mean loss was 5.841026544570923
# Val mAP: 0.8577103614807129
# 100%|██████████| 155/155 [03:05<00:00,  1.19s/it, loss=6.3]
# Mean loss was 5.372860200943485
# Val mAP: 0.8376750946044922
# 100%|██████████| 155/155 [03:05<00:00,  1.20s/it, loss=5.64]
# Mean loss was 4.92951535870952
# Val mAP: 0.8493576049804688
# 100%|██████████| 155/155 [03:04<00:00,  1.19s/it, loss=6.05]
# Mean loss was 4.668849311336395
# Val mAP: 0.8453437685966492
# 100%|██████████| 155/155 [03:06<00:00,  1.20s/it, loss=6.1]
# Mean loss was 5.516878737172773
# Val mAP: 0.8384642601013184
# 100%|██████████| 155/155 [03:02<00:00,  1.17s/it, loss=5.41]
# Mean loss was 7.486589219493251
# Val mAP: 0.8551076054573059
# 100%|██████████| 155/155 [03:02<00:00,  1.18s/it, loss=4.73]
# Mean loss was 5.34126599373356
# Val mAP: 0.7138901352882385
# 100%|██████████| 155/155 [03:05<00:00,  1.19s/it, loss=4.1]
# Mean loss was 5.730128748186173
# Val mAP: 0.8270418047904968
# 100%|██████████| 155/155 [03:01<00:00,  1.17s/it, loss=4.84]
# Mean loss was 6.0154557704925535

# %%
plt.plot(log_train)
plt.xlabel("Epochs")
plt.ylabel("Mean Loss")
plt.legend(["Train Loss"])

# %%
plt.plot(val_mAp)
plt.xlabel("Epochs")
plt.ylabel("mAp")
plt.legend(["Validation mAp"])

# %% [markdown]
# ###Inference

# %%
LOAD_MODEL_FILE = "/content/drive/MyDrive/CS5242/41_model.pth.tar"

load_checkpoint(torch.load(LOAD_MODEL_FILE), model, optimizer)

for x, y in test_loader:
  x = x.to(DEVICE)
  for idx in range(8):
      bboxes = cellboxes_to_boxes(model(x))
      bboxes = non_max_suppression(bboxes[idx], iou_threshold=0.5, threshold=0.4, box_format="midpoint")

      plot_image(x[idx].permute(1,2,0).to("cpu"), bboxes)

  break

# %%
import shutil

shutil.move("/content/41_model.pth.tar", "/content/drive/MyDrive/CS5242/41_model.pth.tar" )
# Out:
# '/content/drive/MyDrive/CS5242/41_model.pth.tar'

# %%
#Calculating the mAP on the test dataset

pred_boxes, target_boxes = get_bboxes(
        test_loader, model, iou_threshold=0.5, threshold=0.4
    )

mean_avg_prec = mean_average_precision(
    pred_boxes, target_boxes, iou_threshold=0.5, box_format="midpoint"
)
print(f"Test mAP: {mean_avg_prec}")
# Out:
# Test mAP: 0.8481650352478027
